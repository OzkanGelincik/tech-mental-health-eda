# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame(
    [[1,3,7,10],[2,6,4,1],[4,8,5,3],[3,7,1,9],[5,9,2,11]],
    index=['r1','r2','r3','r4','r5'],
    columns=['c1','c2','c3','c4']
)

df
# Out:
#     c1  c2  c3  c4
# r1   1   3   7  10
# r2   2   6   4   1
# r3   4   8   5   3
# r4   3   7   1   9
# r5   5   9   2  11

# %%
row_sums=df.sum(axis=1)
row_sums
# Out:
# r1    21
# r2    13
# r3    20
# r4    20
# r5    27
# dtype: int64

# %%
col_sums=df.sum(axis=0)
col_sums
# Out:
# c1    15
# c2    33
# c3    19
# c4    34
# dtype: int64

# %%
df.div(row_sums, axis=0)
# Out:
#           c1        c2        c3        c4
# r1  0.047619  0.142857  0.333333  0.476190
# r2  0.153846  0.461538  0.307692  0.076923
# r3  0.200000  0.400000  0.250000  0.150000
# r4  0.150000  0.350000  0.050000  0.450000
# r5  0.185185  0.333333  0.074074  0.407407

# %% [markdown]
# * `axis=0` tells pandas to align the right-hand Series by rows (index).
#
# * So each row is divided by its own row total.

# %%
df.div(col_sums, axis=1)
# Out:
#           c1        c2        c3        c4
# r1  0.066667  0.090909  0.368421  0.294118
# r2  0.133333  0.181818  0.210526  0.029412
# r3  0.266667  0.242424  0.263158  0.088235
# r4  0.200000  0.212121  0.052632  0.264706
# r5  0.333333  0.272727  0.105263  0.323529

# %% [markdown]
# * `axis=1` tells pandas to align the Series by columns.
#
# * So each column is divided by its column total.

# %% [markdown]
# Mental model
#
# * `sum(axis=1)` → row totals; `sum(axis=0)` → column totals.
#
# * `.div(series, axis=0)` → divide row-wise (match by row labels).
#
# * `.div(series, axis=1)` → divide column-wise (match by column labels).
#
# * ***Alignment is by labels, not position—so order can differ and it still works.***

# %% [markdown]
# REMEMBER THAT IN THE TECH MENTAL HEALTH PROJECT
#
# If you’re normalizing rows (each row sums to 1 or 100%), you should:

# %%
# ct_pct = ct.div(ct.sum(axis=1).replace(0, np.nan), axis=0) * 100

# %%
df.div(df.sum(axis=1), axis='index')    # row percentages
# Out:
#           c1        c2        c3        c4
# r1  0.047619  0.142857  0.333333  0.476190
# r2  0.153846  0.461538  0.307692  0.076923
# r3  0.200000  0.400000  0.250000  0.150000
# r4  0.150000  0.350000  0.050000  0.450000
# r5  0.185185  0.333333  0.074074  0.407407

# %%
df.div(df.sum(axis=0), axis='columns')  # column percentages
# Out:
#           c1        c2        c3        c4
# r1  0.066667  0.090909  0.368421  0.294118
# r2  0.133333  0.181818  0.210526  0.029412
# r3  0.266667  0.242424  0.263158  0.088235
# r4  0.200000  0.212121  0.052632  0.264706
# r5  0.333333  0.272727  0.105263  0.323529

# %%
x = [1,2,3,4,5]

type(x)
# Out:
# list

# %%
df = pd.DataFrame([
    [1,2,3],
    [4,5,6],
    [7,8,9]
], columns=["a", "b", "c"])

df
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# dtype: object

# %%
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
["a", "c"] in list(df.columns)
# Out:
# False

# %%
[el in ["a", "c"] for el in list(df.columns)]
# Out:
# [True, False, True]

# %%
df.loc[:, [True, False, True]]
# Out:
#    a  c
# 0  1  3
# 1  4  6
# 2  7  9

# %% [markdown]
# <h1 style="text-align:center; color:red">Importing Libraries</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # type: ignore

# %% [markdown]
# <h1 style="text-align:center; color:red">Dataset Information</h1>
#
# This dataset is from a 2014 survey that measures attitudes towards mental health and frequency of mental health disorders in the tech workplace.
#
# Source: Kaggle
#
# Owner: Open Sourcing Mental Illness, LTD
#
# Link: [Mental Health in Tech Survey](https://www.kaggle.com/datasets/osmi/mental-health-in-tech-survey)
#
# <div> </div>
#
# Content:
#
# This dataset contains the following data:
#
# * `Timestamp`
#
# * `Age`
#
# * `Gender`
#
# * `Country`
#
# * `state`: If you live in the United States, which state or territory do you live in?
#
# * `self_employed`: Are you self-employed?
#
# * `family_history`: Do you have a family history of mental illness?
#
# * `treatment`: Have you sought treatment for a mental health condition?
#
# * `work_interfere`: If you have a mental health condition, do you feel that it interferes with your work?
#
# * `no_employees`: How many employees does your company or organization have?
#
# * `remote_work`: Do you work remotely (outside of an office) at least 50% of the time?
#
# * `tech_company`: Is your employer primarily a tech company/organization?
#
# * `benefits`: Does your employer provide mental health benefits?
#
# * `care_options`: Do you know the options for mental health care your employer provides?
#
# * `wellness_program`: Has your employer ever discussed mental health as part of an employee wellness program?
#
# * `seek_help`: Does your employer provide resources to learn more about mental health issues and how to seek help?
#
# * `anonymity`: Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
#
# * `leave`: How easy is it for you to take medical leave for a mental health condition?
#
# * `mental_health_consequence`: Do you think that discussing a mental health issue with your employer would have negative consequences?
#
# * `phys_health_consequence`: Do you think that discussing a physical health issue with your employer would have negative consequences?
#
# * `coworkers`: Would you be willing to discuss a mental health issue with your coworkers?
#
# * `supervisor`: Would you be willing to discuss a mental health issue with your direct supervisor(s)?
#
# * `mental_health_interview`: Would you bring up a mental health issue with a potential employer in an interview?
#
# * `phys_health_interview`: Would you bring up a physical health issue with a potential employer in an interview?
#
# * `mental_vs_physical`: Do you feel that your employer takes mental health as seriously as physical health?
#
# * `obs_consequence`: Have you heard of or observed negative consequences for coworkers with mental health conditions in your workplace?
#
# * `comments`: Any additional notes or comments

# %% [markdown]
# <h1 style="text-align:center; color:red">Inspecting the Data</h1>

# %% [markdown]
# * Reading the data and parsing the `Timestamp` variable

# %%
df = pd.read_csv("survey.csv", parse_dates=["Timestamp"])
print(df["Timestamp"].dtype)  # datetime64[ns] if it worked
# Out:
# datetime64[ns]

# %% [markdown]
# * Inspecting the data

# %%
df.head(n=10)
# Out:
#             Timestamp  Age  Gender         Country state self_employed  \
# 0 2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1 2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2 2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3 2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4 2014-08-27 11:30:22   31    Male   United States    TX           NaN
# 5 2014-08-27 11:31:22   33    Male   United States    TN           NaN
# 6 2014-08-27 11:31:50   35  Female   United States    MI           NaN
# 7 2014-08-27 11:32:05   39       M          Canada   NaN           NaN
# 8 2014-08-27 11:32:39   42  Female   United States    IL           NaN
# 9 2014-08-27 11:32:43   23    Male          Canada   NaN           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# ...

# %% [markdown]
# <h1 style="text-align:center;color:red">Checking shape, missing values, and unique values</h1>

# %% [markdown]
# * Inspecting the shape of the data

# %%
df.shape
# Out:
# (1259, 27)

# %% [markdown]
# * Inspecting missingness in the data

# %%
df.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
df.columns = df.columns.str.lower()

# %%
print(df.isna().sum().rename("n_missing"))
print(df.isna().sum().reset_index(name="n_missing"))
# Out:
# timestamp                       0
# age                             0
# gender                          0
# country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# ...

# %%
# 1) Missing counts (+ percent for annotation)
miss_cnt = df.isna().sum().rename("n_missing")
miss_pct = (df.isna().mean()*100).rename("pct_missing")

# 1) Missing counts (+ percent for annotation)
miss = (
    pd.concat([miss_cnt, miss_pct], axis=1)
      .reset_index(names="column")
      .query("n_missing > 0")                     # drop columns with 0 missing
      .sort_values("n_missing", ascending=False)  # largest first
)

# 2) Plot
plt.figure(figsize=(8, max(4, 0.35*len(miss))))
g = sns.barplot(data=miss, x="n_missing", y="column", orient="h")
g.set(
    title="Missing values by column",
    xlabel="Number of missing values",
    ylabel="",
    xlim=(0,1200)
)

# 3) Annotate % missing
for i, (cnt, pct) in enumerate(zip(miss["n_missing"], miss["pct_missing"])):
    g.text(cnt + 1, i, f"{pct:.1f}%", va="center")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Checking unique values of `benefits`, `care_options`, `seek_helo`, and `anonymity` variables

# %% [markdown]
# * These variables will be used to construct feature(s) that measures the level of support an employee receives

# %%
print(df["benefits"].unique()) # Does your employer provide mental health benefits?
print(df["care_options"].unique()) # Do you know the options for mental health care your employer provides?
print((df["seek_help"].unique())) # Does your employer provide resources to learn more about mental health issues and how to seek help?
print(df["anonymity"].unique()) # Does your employer provide resources to learn more about mental health issues and how to seek help?
print(df["wellness_program"].unique()) # Has your employer ever discussed mental health as part of an employee wellness program?
# Out:
# ['Yes' "Don't know" 'No']
# ['Not sure' 'No' 'Yes']
# ['Yes' "Don't know" 'No']
# ['Yes' "Don't know" 'No']
# ['No' "Don't know" 'Yes']

# %% [markdown]
# <span style="color:pink">Note: feature values are uniform and clean, requiring no further cleaning</span>

# %% [markdown]
# #### Checking unique values of `mental_health_consequence`, `phys_health_consequence`, `mental_health_interview`, and `phys_health_interview` variables

# %% [markdown]
# * These variables will be used to construct feature(s) that measures the level of stigma an employee experiences

# %%
print(df["mental_health_consequence"].unique()) # Do you think that discussing a mental health issue with your employer would have negative consequences?
print(df["phys_health_consequence"].unique()) # Do you think that discussing a physical health issue with your employer would have negative consequences?
print((df["mental_health_interview"].unique())) # Would you bring up a mental health issue with a potential employer in an interview?
print(df["phys_health_interview"].unique()) # Would you bring up a physical health issue with a potential employer in an interview?
# Out:
# ['No' 'Maybe' 'Yes']
# ['No' 'Yes' 'Maybe']
# ['No' 'Yes' 'Maybe']
# ['Maybe' 'No' 'Yes']

# %% [markdown]
# <span style="color: pink">Note: feature values are uniform and clean, requiring no further cleaning</span>

# %%
# %pip install -q wordcloud
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
df["remote_work"].value_counts()
# Out:
# remote_work
# No     883
# Yes    376
# Name: count, dtype: int64

# %% [markdown]
# <h1 style="text-align:center; color:red">Feature Engineering</h1>

# %% [markdown]
# ## <span style="color:magenta"> 0. Defining lookup dictionaries (what to turn each string into)</span>

# %% [markdown]
# `support_map`:
# * Creates a dictionary that maps text answers to numbers.
# * Here, any “supportive” answer ("yes") becomes 1. Everything else becomes 0.
#
# `consequence_map`:
# * Another dictionary for a different kind of question.
# * Saying Yes/Maybe to “negative consequences” = more stigma → code as 1.
# * Saying No = no stigma → 0.
#
# `willingness_map`:
# * For “would you discuss?” questions:
# * Yes (willing) = 0 (not unfavorable),
# * Maybe/No (reluctance) = 1 (unfavorable).

# %%
# Policies/visibility (supportive = 1)
support_map = {"Yes": 1, "No": 0, "Don't know":0, "Not sure": 0}

# 2) Negative consequence items (stigma = 1)
# e.g., "Do you think discussing mental health could have negative consequences?"
consequence_map = {"Yes": 1, "Maybe": 1, "No": 0}

# 3) Willingness/comfort items (unfavorable reluctance = 1)
# e.g., "Would you bring up a mental health issue with your employer?"
willingness_map = {"Yes": 0, "Maybe": 1, "No": 1}

# %% [markdown]
# ## <span style="color:magenta"> 1. Building a support score (0-5)</span>
#
# * `.map(support_map)` → convert strings to 0/1 using the dictionary.
# * `.fillna(0)` → if a value didn’t match (missing or unexpected text), treat it as 0.
# * Repeat for four policy columns, then add them together.
# * Result: `support_score` is 0–5 (how many supportive policies a person reports).

# %%
# support_score indicates the level of support an employee receives (higher is better)
df['support_score'] = (
    df["benefits"].map(support_map).fillna(0) + # benefits: Does your employer provide mental health benefits?
    df["care_options"].map(support_map).fillna(0) + # care_options: Do you know the options for mental health care your employer provides?
    df["seek_help"].map(support_map).fillna(0) + # seek_help: Does your employer provide resources to learn more about mental health issues and how to seek help?
    df["anonymity"].map(support_map).fillna(0) + # anonymity: Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
    df["wellness_program"].map(support_map).fillna(0) # wellness_program: Has your employer ever discussed mental health as part of an employee wellness program?
)

# %% [markdown]
# * Confirming the distribution of the `support_score` within the sample

# %%
# Check the distributions
df["support_score"].value_counts(dropna=False).sort_index()
# Out:
# support_score
# 0    517
# 1    251
# 2    203
# 3    115
# 4     92
# 5     81
# Name: count, dtype: int64

# %%
# See the first few rows of what got produced
df[["benefits","care_options","seek_help","anonymity","support_score"]].head()
# Out:
#      benefits care_options   seek_help   anonymity  support_score
# 0         Yes     Not sure         Yes         Yes              3
# 1  Don't know           No  Don't know  Don't know              0
# 2          No           No          No  Don't know              0
# 3          No          Yes          No          No              1
# 4         Yes           No  Don't know  Don't know              1

# %% [markdown]
# ## <span style="color:magenta"> 2. Building a stigma index (0-4)</span>
#
# * Same idea: map → fill missing with 0 → sum.
# * Combines two “consequence” items and two “willingness” items into one score.
# * Larger number = more stigma/reluctance overall.

# %%
# stigma_index indicates the level of stigma an employee encounters (higher is worse)
df['stigma_index'] = (
    df['mental_health_consequence'].map(consequence_map).fillna(0) + # mental_health_consequence: Do you think that discussing a mental health issue with your employer would have negative consequences?
    df['phys_health_consequence'].map(consequence_map).fillna(0) + # phys_health_consequence: Do you think that discussing a physical health issue with your employer would have negative consequences?
    df['mental_health_interview'].map(willingness_map).fillna(0) + # mental_health_interview: Would you bring up a mental health issue with a potential employer in an interview?
    df['phys_health_interview'].map(willingness_map).fillna(0) # phys_health_interview: Would you bring up a physical health issue with a potential employer in an interview?
)

# %% [markdown]
# * Confirming the distribution of the `stigma_index` within the sample

# %%
df["stigma_index"].value_counts(dropna=False).sort_index()
# Out:
# stigma_index
# 0     32
# 1     71
# 2    469
# 3    382
# 4    305
# Name: count, dtype: int64

# %% [markdown]
# ## <span style="color:magenta"> 3. Building parity gap features (mental vs physical)</span>
#
# #### 1. Consequence parity gap
#
# * Take the coded mental consequence score minus the physical one.
# * Positive result → mental health is treated worse than physical (more “yes/maybe” to negative consequences for mental).

# %%
df["parity_gap_consequence"] = (
    df["mental_health_consequence"].map(consequence_map).fillna(0) - # mental_health_consequence: Do you think that discussing a mental health issue with your employer would have negative consequences?
    df["phys_health_consequence"].map(consequence_map).fillna(0) # phys_health_consequence: Do you think that discussing a physical health issue with your employer would have negative consequences?
)

# %%
df["parity_gap_consequence"].unique()
# Out:
# array([ 0,  1, -1])

# %% [markdown]
# * Converting the `parity_gap_consequence` to categorical for plotting

# %%
from pandas.api.types import CategoricalDtype

gap_label = {-1: "Physical worse", 0: "No gap", 1: "Mental worse"}
order_lbl = ["Physical worse", "No gap", "Mental worse"]
gap_dtype = CategoricalDtype(order_lbl, ordered=True)

# Consequence gap: numeric -> labels -> ordered categorical
s = pd.to_numeric(df["parity_gap_consequence"], errors="coerce")
s = s.map(gap_label)
df["parity_gap_consequence_cat"] = s.astype(gap_dtype)

# %% [markdown]
# <span style="color: pink">Values must match exactly `(-1, 0, 1)`. Anything else becomes `NaN`. However, since there is no `NaN`s, we don't have to assign a category to them. However, If you ever want an explicit “Unknown” bucket, add it to the dtype and fill:</span>

# %%
# Keep this commented out
# add at dtype definition time
# gap_dtype_unknown = CategoricalDtype(order_lbl + ["Unknown"], ordered=True)

# s = pd.to_numeric(df["parity_gap_consequence"], errors="coerce").map(gap_label)
# df["parity_gap_consequence_cat"] = s.fillna("Unknown").astype(gap_dtype_unknown)
# or: s.astype(gap_dtype_unknown).cat.add_categories(["Unknown"]).fillna("Unknown")

# %% [markdown]
# #### 2. Consequence categories with four bins
#
# Combine into 4 categories
#
# A compact trick is to encode the pair as code = m*2 + p (so codes are 0,1,2,3):
# * 0 → neither bad
# * 1 → physical bad, mental not
# * 2 → mental bad, physical not
# * 3 → both bad

# %%
consequence_map = {"Yes": 1, "Maybe": 1, "No": 0}

m = df["mental_health_consequence"].map(consequence_map).fillna(0).astype(int)
p = df["phys_health_consequence"].map(consequence_map).fillna(0).astype(int)

codes=2*m + p

code_labels={
    2: "Mental bad physical not",
    0: "Neither mental nor physical bad",
    3: "Both mental and physical bad",
    1: "Pyhsical bad mental not"
}

order = ["Mental bad physical not",
         "Both mental and physical bad",
         "Neither mental nor physical bad",
         "Pyhsical bad mental not"]

df["consequence_4cat"] = pd.Categorical(codes.map(code_labels), categories=order, ordered=True)

# %% [markdown]
# Sanity check:

# %%
df["consequence_4cat"].value_counts()
# Out:
# consequence_4cat
# Neither mental nor physical bad    482
# Mental bad physical not            443
# Both mental and physical bad       326
# Pyhsical bad mental not              8
# Name: count, dtype: int64

# %% [markdown]
# #### 3. Willingness parity gap
#
# * Same idea for willingness to discuss in interviews.
# * Positive result → more reluctance to discuss mental vs physical health.

# %%
df["parity_gap_interview"] = (
    df["mental_health_interview"].map(willingness_map).fillna(0) -
    df["phys_health_interview"].map(willingness_map).fillna(0) 
)

# %%
df["parity_gap_interview"].unique()
# Out:
# array([ 0,  1, -1])

# %% [markdown]
# * Converting the `parity_gap_interview` to categorical for plotting

# %%
gap_label = {-1: "Physical worse", 0: "No gap", 1: "Mental worse"}
order_lbl = ["Physical worse", "No gap", "Mental worse"]
gap_dtype = CategoricalDtype(order_lbl, ordered=True)

# Interview gap: numeric -> labels -> ordered categorical
s = pd.to_numeric(df["parity_gap_interview"], errors="coerce")
s = s.map(gap_label)
df["parity_gap_interview_cat"] = s.astype(gap_dtype)

# %% [markdown]
# * Inspecting the distribution of the `parity_gap_consequence_cat` and `parity_gap_interview_cat` features within the population

# %%
# (optional) quick checks
print(df["parity_gap_consequence_cat"].value_counts(dropna=False))
print(df["parity_gap_interview_cat"].value_counts(dropna=False))
# Out:
# parity_gap_consequence_cat
# No gap            808
# Mental worse      443
# Physical worse      8
# Name: count, dtype: int64
# parity_gap_interview_cat
# No gap            1095
# Mental worse       161
# Physical worse       3
# Name: count, dtype: int64

# %% [markdown]
# * Checking the correlation between parity gaps to potentially create a new composite feature

# %%
rho = df["parity_gap_consequence"].corr(df["parity_gap_interview"], method="pearson")

print(rho)
# Out:
# 0.09802002821737697

# %% [markdown]
# <span style="color: pink"> Since the correlation coefficient is low, these two features will be kept separate.</span>

# %% [markdown]
# ## <span style="color:magenta">4. Creating work interference severity score</span>

# %%
df['work_interfere'].unique() # work interference: If you have a mental health condition, do you feel that it interferes with your work?
# Out:
# array(['Often', 'Rarely', 'Never', 'Sometimes', nan], dtype=object)

# %%
wi_order = {"Never": 0, "Rarely": 1, "Sometimes": 2, "Often": 3} # leave missing values as a separate category 
df["work_interfere_sev"] = df["work_interfere"].map(wi_order)

# %%
wi_order_2 = {"Never": 0, "Rarely": 1, "Sometimes": 1, "Often": 1} # leave missing values as a separate category 
df["work_interfere_sev_2"] = df["work_interfere"].map(wi_order_2)

# %% [markdown]
# ## <span style="color:magenta"> 5. Reviewing `Gender` column values and normalizing </span>

# %%
df["gender"].unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %% [markdown]
# ***Tiny regex cheat-sheet for this function***
#
# * `\b` — word boundary. Prevents matching “male” inside “female”.
# * `|` — OR. Example: male|man matches either.
# * `.` — any single character (except newline).
# * `.*` — zero or more of any character → “anything in between”.
# * `.?` — zero or one character → optional separator (e.g., hyphen or space).
# * `re.search(pattern, s)` — finds the first match anywhere in the string.

# %%
import re

# Defining a function that takes one cell from Gender and returns a clean label (string).

def clean_gender(val: object) -> str:
    if pd.isna(val):
        return "Unknown/Other"
    
    s = str(val).strip().casefold()

    fixes = {
        "f": "female", "m": "male",
        "female": "female", "femake": "female", "femail": "female",
        "male": "male", "maile": "male", "mal": "male", "malr":"male", "msle": "male", "mail": "male", "make": "male", 
        "cis female": "cis female", "cis-female/femme": "cis female",
        "cis male": "cis male", "male (cis)": "cis male",
        "trans female": "trans female", "female (trans)": "trans female", "trans woman": "trans female"
    }

    s = fixes.get(s, s) # looks up s in the dict; if not found, it keeps s unchanged

    if s in {"", "nah", "all", "p", "a little about you"}:
        return "Unknown/Other"
    
    # building boolean flags with regex

    has_trans = bool(re.search(r"\btrans", s)) # \b would boundry, matching words beginning with "trans", bool() converts to True/False
    has_male = bool(re.search(r"\bmale\b|\bman\b|guy|-ish.*male", s)) # \bmale\b and \bmman\b(whole male and man words), “-ish” followed by any characters (.*) then “male”
    has_female = bool(re.search(r"\bfemale\b|\bwoman\b", s))
    has_nb = bool(re.search("non.?binary|enby|genderqueer|agender|androgyne|androgyn|fluid|neuter", s)) # “non” + optional char (.?) + “binary”, so it matches nonbinary and non-binary, NB/GNC terms: enby, genderqueer, agender, androgyne, fluid, neuter


    she_they = "she/they" in s or "they/she" in s 
    kinda_male = "something kinda male" in s 
    if she_they or kinda_male: # Non-regex string checks for patterns we want to treat as non-binary/GNC signals
        has_nb = True

    if has_trans and has_male: # they mention “trans” and male term, classify as Trans man
        return "Trans man"
    if has_trans and has_female: # they mention “trans” and female term, classify as Trans woman
        return "Trans woman"
    
    if has_nb:
        return "Non-binary_GNC" # catch non-binary/gender-nonconforming identities
    
    if "cis female" in s or (has_female and not has_male):
        return "Woman"
    
    if "cis male" in s or (has_male and not has_female):
        return "Man"

    if has_female and has_male: # mixed signals → treat as GNC
        return "Non-binary_GNC"
    
    else:
        return "Unknown/Other"

# %% [markdown]
# #### Applying `clean_gender()` function to the `Gender` column

# %%
df["gender_5"] = df["gender"].apply(clean_gender)

df["gender_3"] = df["gender_5"].replace({"Trans woman": "Woman", "Trans man": "Man"})

df["gender_3_alt"] = df["gender_5"].replace({"Trans woman": "Non-binary_GNC", "Trans man": "Non-binary_GNC"})

df["gender_3_alt"] = df["gender_3_alt"].replace({"Non-binary_GNC": "Trans_Non-binary_GNC", "Non-binary_GNC": "Trans_Non-binary_GNC"})

# %%
print(df["gender_5"].value_counts(dropna=False))
print(df["gender_3"].value_counts(dropna=False))
print(df["gender_3_alt"].value_counts(dropna=False))
# Out:
# gender_5
# Man               993
# Woman             247
# Non-binary_GNC     10
# Unknown/Other       5
# Trans woman         4
# Name: count, dtype: int64
# gender_3
# Man               993
# Woman             251
# Non-binary_GNC     10
# Unknown/Other       5
# Name: count, dtype: int64
# gender_3_alt
# Man                     993
# Woman                   247
# Trans_Non-binary_GNC     14
# Unknown/Other             5
# Name: count, dtype: int64

# %% [markdown]
# ## <span style="color:magenta">6. Creating a categorical `Age` variable: `age_cat`</span>
#
# * Building a boolean Series that’s True for outliers:
#     * `.lt(18)` means “less than 18” (same as age < 18).
#     * `.gt(80)` means “greater than 80” (same as age > 80).
#     * `|` is the element-wise OR for boolean Series.
# * Result: True where age is <18 or >80, else False.

# %% [markdown]
# #### Ensuring `Age` variable is numeric before binning

# %%
df["age"].unique()
# Out:
# array([         37,          44,          32,          31,          33,
#                 35,          39,          42,          23,          29,
#                 36,          27,          46,          41,          34,
#                 30,          40,          38,          50,          24,
#                 18,          28,          26,          22,          19,
#                 25,          45,          21,         -29,          43,
#                 56,          60,          54,         329,          55,
#        99999999999,          48,          20,          57,          58,
#                 47,          62,          51,          65,          49,
#              -1726,           5,          53,          61,           8,
#                 11,          -1,          72])

# %%
df["age"].dtype
# Out:
# dtype('int64')

# %%
age = pd.to_numeric(df["age"], errors="coerce")

# %% [markdown]
# #### Defining the outliers
#
# * Saving the `outlier` flag in `df` to filter or describe outliers later

# %%
outlier = age.lt(18)| age.gt(80)

df["age_outlier"] = outlier

# %% [markdown]
# #### Creating `age_cat` binned variable

# %%
bins   = [0, 25, 35, 45, np.inf]
labels = ["<25", "25–34", "35–44", "45+"]

age_cat = df["age_cat"] = pd.cut(
    age.where(~outlier),
    bins=bins,
    labels=labels,
    right=False,
    include_lowest=True
)

# %% [markdown]
# * Confirming `age_cat`'s data type and, categories, and missing values

# %%
print(age_cat.dtype)
print(age_cat.cat.categories) 
print(age_cat.isna())
# Out:
# category
# Index(['<25', '25–34', '35–44', '45+'], dtype='object')
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1254    False
# 1255    False
# 1256    False
# 1257    False
# 1258    False
# Name: age, Length: 1259, dtype: bool

# %% [markdown]
# #### Adding two categories (`"Unknown"` `"Outlier"`) to the `age_cat` to annotate the `NaN`s

# %% [markdown]
# Because `NaN` isn’t a category, we need to add two new categories ("Unknown" and "Outlier") to `df["age_cat"]` to specify the `NaN`

# %%
age_cat = age_cat.cat.add_categories(["Unknown", "Outlier"])
age_cat[age_cat.isna()] = "Unknown"
age_cat[outlier] = "Outlier"

df["age_cat"] = age_cat

df["age_cat"]
# Out:
# 0       35–44
# 1       35–44
# 2       25–34
# 3       25–34
# 4       25–34
#         ...
# 1254    25–34
# 1255    25–34
# 1256    25–34
# 1257      45+
# 1258    25–34
# Name: age_cat, Length: 1259, dtype: category
# Categories (6, object): ['<25' < '25–34' < '35–44' < '45+' < 'Unknown' < 'Outlier']

# %% [markdown]
# ## <span style="color:magenta">7. Cleaning `no_employees` and creating `company_size` (and related additional features)</span>

# %%
df["no_employees"].unique()
# Out:
# array(['6-25', 'More than 1000', '26-100', '100-500', '1-5', '500-1000'],
#       dtype=object)

# %% [markdown]
# #### Creating an ordered categorical variable for company size

# %%
norm = lambda s: s.astype("string").str.strip().str.casefold()

raw = norm(df["no_employees"])

raw = (raw
       .str.replace("\u2013", "-", regex=False)   # en dash –
       .str.replace("\u2014", "-", regex=False))  # em dash —

cat_map = {
    "1-5": "1-5",
    "6-25": "6-25",
    "26-100": "26-100",
    "100-500": "100-500",
    "500-1000": "500-1000",
    "1000+": "1000+",
    "more than 1000": "1000+"
}

df["company_size_cat"] = raw.map(cat_map) # unmatched ware labelled as NaN

order = ["1-5","6-25","26-100","100-500","500-1000","1000+","Unknown"]

df["company_size_cat"] = (df["company_size_cat"]
                             .fillna("Unknown")
                             .astype(pd.CategoricalDtype(order, ordered=True))
)

cat_map2 = {
    "1-5": "≤100",
    "6-25": "≤100",
    "26-100": "≤100",
    "100-500": "100-500",
    "500-1000": "≥500",
    "1000+": "≥500",
    "more than 1000": "≥500"
}

df["company_size_cat2"] = raw.map(cat_map2)

order2 = ["≤100", "100-500", "≥500"]

df["company_size_cat2"] = (df["company_size_cat2"]
                               .fillna("Unknown")
                               .astype(CategoricalDtype(categories=order2, ordered=True))
)

# %% [markdown]
# #### Creating an ordinal variable for company size

# %%
ord_map = {"1-5": 0, "6-25": 1, "26-100": 2, "100-500":3, "500-1000": 4, "1000+": 5, "Unknown":pd.NA}

df["company_size_ord"] = df["company_size_cat"].map(ord_map).astype("Int64")

# %% [markdown]
# ##### Confirming successful creation of `company_size_cat` feature

# %%
print(df["company_size_cat"].value_counts(dropna=False))
# Out:
# company_size_cat
# 6-25        290
# 26-100      289
# 1000+       282
# 100-500     176
# 1-5         162
# 500-1000     60
# Unknown       0
# Name: count, dtype: int64

# %% [markdown]
# <span style="color: pink">Since there is no `"Unknown"` category, we'll remove it. This will come in handy when plotting</span>

# %%
df["company_size_cat"] = df["company_size_cat"].cat.remove_unused_categories()

# %% [markdown]
# ##### Confirming successful creating of `company_size_ord` feature

# %%
print(df["company_size_ord"].value_counts(dropna=False))
# Out:
# company_size_ord
# 1    290
# 2    289
# 5    282
# 3    176
# 0    162
# 4     60
# Name: count, dtype: Int64

# %%
print(df[["no_employees","company_size_cat","company_size_ord"]].head())
# Out:
#      no_employees company_size_cat  company_size_ord
# 0            6-25             6-25                 1
# 1  More than 1000            1000+                 5
# 2            6-25             6-25                 1
# 3          26-100           26-100                 2
# 4         100-500          100-500                 3

# %% [markdown]
# ## <span style="color:magenta">8. Creating Manager/Coworker Comfort features</span>

# %%
print(df["supervisor"].unique())
print(df["coworkers"].unique())
# Out:
# ['Yes' 'No' 'Some of them']
# ['Some of them' 'No' 'Yes']

# %% [markdown]
# #### 1. Creating two ordered categorial variable (for plotting): supervisor or coworkers comfort

# %%
order={"Yes", "Some of them", "No"}
df["comfort_supervisor_cat"] = df["supervisor"].astype(pd.CategoricalDtype(categories= order,ordered=True))
df["comfort_coworkers_cat"] = df["coworkers"].astype(pd.CategoricalDtype(categories= order,ordered=True))

# %% [markdown]
#  <div class="alert alert-info">
# <b>Note:</b> Values must match exactly `("Yes", "No", "Some of them")`. Anything else becomes `NaN`. However, since there is no `NaN`s, we don't have to assign a category to them. However, If you ever want an explicit “Unknown” bucket, add it to the dtype and fill:
# </div>

# %%
# Keep this commented out

# comfort_dtype2 = CategoricalDtype(order + ["Unknown"], ordered=True)
# df["comfort_supervisor_cat"] = (
#     df["supervisor"].where(df["supervisor"].isin(order), "Unknown").astype(comfort_dtype2)
# )

# comfort_dtype2 = CategoricalDtype(order + ["Unknown"], ordered=True)
# df["comfort_coworkers_cat"] = (
#     df["coworkers"].where(df["coworkers"].isin(order), "Unknown").astype(comfort_dtype2)
#)

# %%
print(df["comfort_supervisor_cat"].dtype)
print(df["comfort_supervisor_cat"].cat.categories)
print(df["comfort_supervisor_cat"].value_counts(dropna=False))
# Out:
# category
# Index(['No', 'Some of them', 'Yes'], dtype='object')
# comfort_supervisor_cat
# Yes             516
# No              393
# Some of them    350
# Name: count, dtype: int64

# %%
print(df["comfort_coworkers_cat"].dtype)
print(df["comfort_coworkers_cat"].cat.categories)
print(df["comfort_coworkers_cat"].value_counts(dropna=False))
# Out:
# category
# Index(['No', 'Some of them', 'Yes'], dtype='object')
# comfort_coworkers_cat
# Some of them    774
# No              260
# Yes             225
# Name: count, dtype: int64

# %% [markdown]
# #### 2. Creating two ordinal variables: supervisor or coworkers comfort

# %%
ord3 = {"No": 0, "Some of them": 1, "Yes": 2}
df["comfort_supervisor_ord3"] = df["supervisor"].map(ord3).astype("Int64")
df["comfort_coworkers_ord3"] = df["coworkers"].map(ord3).astype("Int64")

# %%
print(df["comfort_supervisor_ord3"].dtype)
print(df["comfort_supervisor_ord3"].value_counts(dropna=False))
# Out:
# Int64
# comfort_supervisor_ord3
# 2    516
# 0    393
# 1    350
# Name: count, dtype: Int64

# %%
print(df["comfort_coworkers_ord3"].dtype)
print(df["comfort_coworkers_ord3"].value_counts(dropna=False))
# Out:
# Int64
# comfort_coworkers_ord3
# 1    774
# 0    260
# 2    225
# Name: count, dtype: Int64

# %% [markdown]
# #### 3. Creating a binary variable for any comfort

# %%
df["comfort_any_bin"] = (
    (df["comfort_supervisor_ord3"].fillna(0)>0) |
    (df["comfort_coworkers_ord3"].fillna(0)>0)
).astype("Int64")

# %%
print(df["comfort_any_bin"].dtype)
print(df["comfort_any_bin"].value_counts(dropna=False))
# Out:
# Int64
# comfort_any_bin
# 1    1060
# 0     199
# Name: count, dtype: Int64

# %% [markdown]
# #### 4. Creating an ordinal variable for total comfort

# %%
df["comfort_total_ord4"] = (
    df["comfort_supervisor_ord3"].fillna(9) +
    df["comfort_coworkers_ord3"].fillna(9)
).astype("Int64")

# %%
print(df["comfort_total_ord4"].dtype)
print(df["comfort_total_ord4"].value_counts(dropna=False))
# Out:
# Int64
# comfort_total_ord4
# 3    332
# 2    297
# 1    236
# 0    199
# 4    195
# Name: count, dtype: Int64

# %% [markdown]
# ## <span style="color:magenta">9. Creating `us_category` feature</span>

# %% [markdown]
# * Checking the unique values of the `Country` column

# %%
df["country"].unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Bulgaria', 'France',
#        'Portugal', 'Netherlands', 'Switzerland', 'Poland', 'Australia',
#        'Germany', 'Russia', 'Mexico', 'Brazil', 'Slovenia', 'Costa Rica',
#        'Austria', 'Ireland', 'India', 'South Africa', 'Italy', 'Sweden',
#        'Colombia', 'Latvia', 'Romania', 'Belgium', 'New Zealand',
#        'Zimbabwe', 'Spain', 'Finland', 'Uruguay', 'Israel',
#        'Bosnia and Herzegovina', 'Hungary', 'Singapore', 'Japan',
#        'Nigeria', 'Croatia', 'Norway', 'Thailand', 'Denmark',
#        'Bahamas, The', 'Greece', 'Moldova', 'Georgia', 'China',
#        'Czech Republic', 'Philippines'], dtype=object)

# %% [markdown]
# <span style="color: pink">Note: the values are clean and uniform, requiring no further cleaning.</span>

# %% [markdown]
# * Checking the unique values of the `Country` column

# %%
df["state"].unique()
# Out:
# array(['IL', 'IN', nan, 'TX', 'TN', 'MI', 'OH', 'CA', 'CT', 'MD', 'NY',
#        'NC', 'MA', 'IA', 'PA', 'WA', 'WI', 'UT', 'NM', 'OR', 'FL', 'MN',
#        'MO', 'AZ', 'CO', 'GA', 'DC', 'NE', 'WV', 'OK', 'KS', 'VA', 'NH',
#        'KY', 'AL', 'NV', 'NJ', 'SC', 'VT', 'SD', 'ID', 'MS', 'RI', 'WY',
#        'LA', 'ME'], dtype=object)

# %% [markdown]
# <span style="color: pink">Note-1: the values are clean and uniform, requiring no further cleaning.</span>
#
# <span style="color: pink">Note-2: It's likely that only `United States` has `state` values available.</span>

# %% [markdown]
# #### Creating the `us_category` feature

# %%
country = df["country"].astype("string").str.strip()

us_cat = country.map({"United States": "US"}).fillna("Non-US")   # map US, others -> NaN, then NaN -> 'Non-US'
us_cat = us_cat.mask(country.isna(), "Unknown") # true missing -> 'Unknown'

dtype = us_cat.astype(pd.CategoricalDtype(categories=["US", "Non-US", "Unknown"]))

df["us_category"] = dtype

# %% [markdown]
# * Inspecting the distribution of the `us_category` to confirm accurate creation

# %%
print(df['us_category'].value_counts(dropna=False))
# Out:
# us_category
# US         751
# Non-US     508
# Unknown      0
# Name: count, dtype: int64

# %% [markdown]
# <h1 style="text-align:center; color:red">Visual Insights (Raw Data)</h1>

# %% [markdown]
# ## <span style="color:orange">Exploring variables</span>

# %% [markdown]
# ### <span style="color:orange">`Age`</span>

# %%
order = df["age"].value_counts().index

g = sns.catplot(y="age", data=df, kind="count", order=order, height=8, aspect=1.1, color="darkred")
g.figure.suptitle("age", y = 1.04)
g.set(xlabel="Count", ylabel="")   
g.figure.subplots_adjust(left=0.1)
plt.show()

# %%
age = pd.to_numeric(df["age"], errors="coerce")

outlier = age.lt(18) | age.gt(80)

df["age_outlier"] = outlier

sns.histplot(df[~df["age_outlier"]]["age"], color="darkblue")
plt.show()

# %%
sns.displot(df[~df["age_outlier"]]["age"],
            kde=True, color="darkblue")
plt.show()

# %% [markdown]
# ### <span style="color:orange">`Gender`</span>

# %%
# Libraries
from wordcloud import WordCloud # type: ignore
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 5), dpi=150)  # width, height in inches

# Create a list of word
freqs = (
    df["gender"]        # or the column you prefer
      .dropna()
      .astype(str)
      .value_counts()
      .to_dict()
)

wc = WordCloud(width=1400, height=700, background_color="white", margin=0)
wc = wc.generate_from_frequencies(freqs)

# Display the generated image:
ax.imshow(wc, interpolation='bilinear')
ax.axis("off")
ax.margins(x=0, y=0)
plt.show()

# %%
df["age_cat_2"] = df["age_cat"].where(df["age_cat"].isin(["<25", "25–34", "35–44", "45+"]), pd.NA)

df["age_cat_2"] = df["age_cat_2"].astype(CategoricalDtype(categories=["<25", "25–34", "35–44", "45+"], ordered=True))

g = sns.catplot(data=df, x="age_cat_2", kind="count", hue=df["gender_5"].astype(CategoricalDtype(categories=["Woman", "Man", "Trans woman", "Non-binary_GNC"], ordered=False)), palette="gist_rainbow")
g.figure.suptitle("Age/Gender breakdown", y = 1.04)
g.set_xlabels("Age band")
g.set_ylabels("Count")
g._legend.set_title("Gender")
plt.show()

# %% [markdown]
# ### <span style="color:orange">`Country`</span>

# %%
order = df["country"].value_counts().index

g = sns.catplot(y="country", data=df, kind="count", order=order, height=8, aspect=1.1, color="red")
g.figure.suptitle("Country", y = 1.04)
g.set(xlabel="Count", ylabel="")           # nicer axis labels
g.figure.subplots_adjust(left=0.1) 
plt.show()

# %% [markdown]
# ***<span style="color:pink">Optional plotting ideas for reference</span>***

# %%
# !python3 -m pip install squarify

# %%
# # libraries
# import squarify    # type: ignore # pip install squarify (algorithm for treemap)

# # Create a data frame 
# d = pd.DataFrame({'nb_people':list(df["Country"].value_counts().reset_index(name="count")["count"]), 'group':list(df["Country"].value_counts().index) })

# # plot it
# squarify.plot(sizes=d['nb_people'], label=d['group'], alpha=.8 )
# plt.axis('off')
# plt.show()

# %%
# !python3 -m pip install pywaffle

# %%
# k = list(df["Country"].value_counts().index)
# v = list(df["Country"].value_counts().reset_index(name="count")["count"])

# # libraries: pyWaffle module
# from pywaffle import Waffle # type: ignore

# # create dictionary 
# benefits_dict = dict(zip(k, v))

# # Basic waffle
# plt.figure(
#   FigureClass=Waffle,
#   rows=10,
#   columns=10,
#   values=benefits_dict,
#   legend={'loc': 'upper left', 'bbox_to_anchor': (1.05, 1)},
# )
# plt.tight_layout()
# plt.title("Country", y = 1.04)
# plt.show()

# %% [markdown]
# ### <span style="color:orange">`mental_vs_physical`: Does the employer take mental health as seriously as physical health?</span>

# %%
g = sns.catplot(data=df, x="mental_vs_physical", kind="count", palette="viridis", hue="mental_vs_physical", order=["Yes", "No", "Don't know"])
g.figure.suptitle("Does your employer take mental health as seriously as physical health?", y = 1.04)
g.set_xlabels("")
g.set_ylabels("Count")
plt.show()

# %% [markdown]
# ### <span style="color:orange">`obs_consequence`: Have you heard of or observed negative consequences for coworkers with mental health issues?</span>

# %%
g = sns.catplot(x="obs_consequence", data=df, kind="count", palette="plasma", hue="obs_consequence", order=["Yes", "No"])
g.figure.suptitle("Have you heard of or observed negative consequences for coworkers with mental health issues?", y = 1.04)
g.set_xlabels("")
g.set_ylabels("Count")
plt.show()

# %% [markdown]
# ### <span style="color:orange">`self_employed`: Are you self employed?</span>

# %%
g = sns.catplot(x="self_employed", data=df, kind="count", palette="magma", legend=False, hue="self_employed")
g.figure.suptitle("Are you self-employed?", y = 1.04)
g.set_xlabels("")
g.set_ylabels("Count")
plt.show()

# %% [markdown]
# ### <span style="color:orange">`tech_company`: Do you primarily work in tech?</span>

# %%
g = sns.catplot(x="tech_company", data=df, kind="count", palette="cubehelix", hue="tech_company")
g.figure.suptitle("Do you primarily work in tech?", y = 1.04)
g.set_xlabels("")
g.set_ylabels("Count")
plt.show()

# %% [markdown]
# ### <span style="color:orange">`treatment`: Have you saught treatment for mental health issue?</span>

# %%
g = sns.catplot(x="treatment", data=df, kind="count", palette="seismic", hue="treatment")
g.figure.suptitle("Have you saught treatment for mental health issue?", y = 1.04)
g.set_xlabels("")
g.set_ylabels("Count")
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <b>Insight:</b>
#
# * The bars for treatment = Yes and No are almost the same height, so among respondents who answered this item, about half report having sought treatment (maybe a slight edge to “Yes”).
#
# </div>

# %% [markdown]
# ### <span style="color:orange">`work_interfere`: Do mental health issues interfere with your work?</span>

# %%
g = sns.catplot(data=df, x="work_interfere", kind="count", order=["Often", "Sometimes", "Rarely", "Never"], palette="cubehelix", legend=False, hue="work_interfere")
g.figure.suptitle("Do mental health issues interfere with your work?", y = 1.04)
g.set_xlabels("Work interference")
g.set_ylabels("Count")
plt.show()

# %%
df["work_interfere_cat_2"] = df["work_interfere"].map({"Never": "Never/Rarely", "Rarely": "Never/Rarely", "Sometimes": "Sometimes/Often", "Often": "Sometimes/Often"}).astype(CategoricalDtype(categories=["Never/Rarely", "Sometimes/Often"]))
df["work_interfere_cat_2"].value_counts()
# Out:
# work_interfere_cat_2
# Sometimes/Often    609
# Never/Rarely       386
# Name: count, dtype: int64

# %%
g = sns.catplot(data=df, x="work_interfere_cat_2", kind="count", order=["Never/Rarely", "Sometimes/Often"], palette="cubehelix", legend=False, hue="work_interfere_cat_2")
g.figure.suptitle("Do mental health issues interfere with your work?", y = 1.04)
g.set_xlabels("")
g.set_ylabels("Count")
plt.show()

# %% [markdown]
# ### <span style="color:orange">`remote_work`: Do you mostly work remotely?</span>

# %%
g = sns.catplot(data=df, x="remote_work", kind="count", palette="cividis", hue="remote_work", order=["Yes", "No"])
g.figure.suptitle("Do you mostly work remotely?", y=1.04)
g.set_xlabels("")
g.set_ylabels("Count")
plt.show()

# %% [markdown]
# ### <span style="color:orange">`mental_health_consequence`: Do you think that discussing a mental health issue with your employer would have negative consequences?</span>

# %%
g = sns.catplot(data=df, x="mental_health_consequence", kind="count", order=["Yes", "Maybe", "No"])
g.figure.suptitle("Do you think that discussing a mental health issue with \nyour employer would have negative consequences?", y=1.1)
g.set_xlabels("")
g.set_ylabels("Count")
plt.show()

# %%
# # keep a desired order
# order = ["Yes", "Maybe", "No"]

# # build tidy table with fixed column names
# d = (df["mental_health_consequence"]
#        .value_counts()
#        .reindex(order, fill_value=0)
#        .rename_axis("group")            # <-- set index name
#        .reset_index(name="nb_people"))  # --> columns: ['group','nb_people']

# # exact colors
# color_map = {"Yes":"#d62728", "Maybe":"#1f77b4", "No":"#2ca02c"}
# colors = [color_map[g] for g in d["group"]]

# # plot
# squarify.plot(
#     sizes=d["nb_people"],
#     label=d["group"],
#     color=colors,
#     alpha=.9,
#     text_kwargs={"fontsize":12}
# )

# plt.axis("off")
# plt.title("Do you think that discussing a mental health issue with \nyour employer would have negative consequences?",color="red", fontsize=14, fontweight="bold")
# plt.show()

# %%
k = list(df["mental_health_consequence"].value_counts().index)
v = list(df["mental_health_consequence"].value_counts().reset_index(name="count")["count"])

# libraries: pyWaffle module
from pywaffle import Waffle # type: ignore

# create dictionary 
benefits_dict = dict(zip(k, v))

# Basic waffle
plt.figure(
  FigureClass=Waffle,
  rows=10,
  columns=10,
  values=benefits_dict,
  legend={'loc': 'upper left', 'bbox_to_anchor': (1.05, 1)},
)
plt.tight_layout()
plt.title("Discussing a mental health issue with your employer has negative consequences.", y = 1.04)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %% [markdown]
# ### <span style="color:orange">`phys_health_consequence`: Do you think that discussing a physical health issue with your employer would have negative consequences?</span>

# %%
g = sns.catplot(data=df, x="phys_health_consequence", kind="count", order=["Yes", "Maybe", "No"])
g.figure.suptitle("Do you think that discussing a physical health issue with \nyour employer would have negative consequences?", y=1.1)
g.set_xlabels("")
g.set_ylabels("Count")
plt.show()

# %%
k = list(df["phys_health_consequence"].value_counts().index)
v = list(df["phys_health_consequence"].value_counts().reset_index(name="count")["count"])

# libraries: pyWaffle module
from pywaffle import Waffle # type: ignore

# create dictionary 
benefits_dict = dict(zip(k, v))

# Basic waffle
plt.figure(
  FigureClass=Waffle,
  rows=10,
  columns=10,
  values=benefits_dict,
  legend={'loc': 'upper left', 'bbox_to_anchor': (1.05, 1)},
)
plt.tight_layout()
plt.title("Discussing a physical health issue with your employer has negative consequences", y = 1.04)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
g = sns.catplot(data=df, x="consequence_4cat", kind="count", hue="consequence_4cat", palette="cubehelix")
g.figure.suptitle("Consequence Concordance", y=1.1)
g.set_xlabels("")
g.set_ylabels("Count")
g.set_xticklabels(rotation=45, ha="right")
plt.show()

# %% [markdown]
# <h1 style="text-align:center; color:red">Visual Insights (includes Composite Features)</h1>

# %% [markdown]
# ## <span style="color:Magenta">Qestion: Do workplace policies (benefits, care options, anonymity, generous leave) correlate with higher treatment-seeking?</span>

# %%
df.groupby("support_score")["treatment"].count().reset_index()
# Out:
#    support_score  treatment
# 0              0        517
# 1              1        251
# 2              2        203
# 3              3        115
# 4              4         92
# 5              5         81

# %% [markdown]
# ### <span style="color:orange">`support score`: Counts</span>

# %% [markdown]
# <span style="color:lightblue"> Quick reminder</span>
# * `treatment`: Have you sought treatment for a mental health condition? <span style="color:pink">(`Yes`->`1`, `No`->`0`)</span>
# * `support_score`: <span style="color:pink">“supportive” answer (`yes`) becomes `1`. Everything else becomes `0`</span>
#     * `benefits`: Does your employer provide mental health benefits?
#     * `care_options`: Do you know the options for mental health care your employer provides?
#     * `seek_help`: Does your employer provide resources to learn more about mental health issues and how to seek help?
#     * `anonymity`: Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
#     * `wellness_program`: Has your employer ever discussed mental health as part of an employee wellness program?

# %%
g = sns.catplot(y="support_score", data=df, kind="count", palette="pastel", hue="support_score", legend=False)
g.figure.suptitle("Distribution of support scores", y = 1.04, color="red", fontsize=14, fontweight="bold")
g.set_xlabels("Count")
g.set_ylabels("Support score")
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <b>Insight:</b>
#
#  * The distribution is heavily skewed to low support.
#
# * Most respondents sit at support=0, then counts drop steadily as support increases; only a small minority report scores 4–5.
#
# * Note: “Don’t know/Not sure” are coded as 0. So the big bar at 0 mixes true absence of policies with low visibility/awareness.
#
#     * That’s important for interpretation: it suggests either few supports exist or employees don’t know about them.
#
# </div>

# %% [markdown]
# ### <span style="color:orange"> Exploring components of `support_score`</span>

# %% [markdown]
# #### <span style="color:pink"> 1. Does your employer provide mental health benefits?</span>

# %%
g = sns.catplot(data=df, x="benefits", kind="count", hue="benefits", palette="magma")

g.set(xlabel="Employer health benefits", ylabel="Number of employees", title="Does your employer provide mental health benefits?") 

plt.show()

# %%
# libraries
import squarify    # type: ignore # pip install squarify (algorithm for treemap)

# keep a desired order
order = ["Yes", "No", "Don't know"]

# build tidy table with fixed column names
d = (df["benefits"]
       .value_counts()
       .reindex(order, fill_value=0)
       .rename_axis("group")            # <-- set index name
       .reset_index(name="nb_people"))  # --> columns: ['group','nb_people']

# exact colors
color_map = {"Yes":"#2ca02c", "No":"#d62728", "Don't know":"#1f77b4"}
colors = [color_map[g] for g in d["group"]]

# plot
squarify.plot(
    sizes=d["nb_people"],
    label=d["group"],
    color=colors,
    alpha=.9,
    text_kwargs={"fontsize":12}
)

plt.axis("off")
plt.title("Does your employer provide mental health benefits?",color="red", fontsize=14, fontweight="bold")
plt.show()

# %%
# k = list(df["benefits"].value_counts().index)
# v = list(df["benefits"].value_counts().reset_index(name="count")["count"])

# # libraries: pyWaffle module
# from pywaffle import Waffle # type: ignore

# # create dictionary 
# benefits_dict = dict(zip(k, v))

# # Basic waffle
# plt.figure(
#   FigureClass=Waffle,
#   rows=10,
#   columns=10,
#   values=benefits_dict,
#   legend={'loc': 'upper left', 'bbox_to_anchor': (1.05, 1)},
# )
# plt.tight_layout()
# plt.title("Does your employer provide mental health benefits?", y = 1.04, color="darkslateblue", fontsize=14, fontweight="bold")
# plt.show()

# %%
df['benefits'] = pd.Categorical(df['benefits'],
                                categories=['Yes', 'No', "Don't know"],
                                ordered=True)

g = sns.histplot(data=df, x="benefits", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Employer health benefits") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Employer health benefits vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
# from matplotlib.ticker import PercentFormatter

# import seaborn as sns
# g = sns.histplot(data=df, x="benefits", hue="treatment",
#              multiple="fill", stat="proportion", shrink=.8,
#              discrete=True, hue_order=["No","Yes"], palette="cubehelix")
# plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
# g.set_xlabel("Employer health benefits") 
# g.set_ylabel("Share of employees")
# g.figure.suptitle("Employer health benefits vs Treatment rate (stacked)")
# plt.show()

# %%
# Add 0/1 for treatment: `treat_bin` to `df`
df["treat_bin"] = df["treatment"].str.strip().str.casefold().map({"yes":1,"no":0}).astype("Int64")

g = sns.barplot(data=df, x="benefits", y="treat_bin", order=["Yes", "No", "Don't know"], palette="colorblind", hue="benefits")
g.set(ylim=(0,1))
g.set_ylabel("Treatment seeking rate")
g.set_xlabel(" Employer health benefits")
g.figure.suptitle("Employer health benefits vs Treatment seeking rate")
plt.show()

# %%
# # masks
# w_mask = df["gender_3_alt"].eq("Woman")
# m_mask = df["gender_3_alt"].eq("Man")
# t_nb_gnc_mask = df["gender_3_alt"].eq("Trans_Non-binary_GNC")

# # pull the binary outcome; drop missing, make numeric arrays
# g_w = df.loc[w_mask, "treat_bin"].dropna().astype(float).to_numpy()
# g_m = df.loc[m_mask, "treat_bin"].dropna().astype(float).to_numpy()
# g_t_nb_gnc = df.loc[t_nb_gnc_mask, "treat_bin"].dropna().astype(float).to_numpy()

# alpha = 0.05

# # Welch's One-way ANOVA 
# f_stat, p_val = stats.f_oneway(g_w, g_m, g_t_nb_gnc, equal_var=False)

# print(f"n_woman={g_w.size}, n_man={g_m.size}, n_trans_nb_gnc={g_t_nb_gnc.size}")
# print(f"mean_woman={g_w.mean():.3f}, mean_man={g_m.mean():.3f}, mean_trans_nb_gnc={g_t_nb_gnc.mean():.3f}")
# print(f"f={f_stat:.3f}, p={p_val:.6f}")

# if p_val < alpha:
#     print("Reject H0: groups differ.")
# else:
#     print("Fail to reject H0: no evidence of a difference.")

# %%
import numpy as np
import pandas as pd
from itertools import combinations
from scipy import stats
from statsmodels.stats.multitest import multipletests

# # masks
# ben_y_mask=df["benefits"].eq("Yes")
# ben_n_mask=df["benefits"].eq("No")
# ben_dk_mask=df["benefits"].eq("Don't know")

# g_ben_y=df.loc[ben_y_mask,"treat_bin"].dropna().astype(float).to_numpy()
# g_ben_n=df.loc[ben_n_mask,"treat_bin"].dropna().astype(float).to_numpy()
# g_ben_dk=df.loc[ben_dk_mask,"treat_bin"].dropna().astype(float).to_numpy()

# 0) Ensure the outcome is numeric 0/1 and drop NAs
y = df["treat_bin"].astype(float)

groups={}

for ben in (df["benefits"].dropna().to_numpy()):
    groups[ben] = y[df["benefits"].eq(ben)].dropna().to_numpy()

# print(groups)

# build a list of dictionaries that hold column values
rows=[]
for g1,g2 in combinations(groups,2):
    x,y_ = groups[g1], groups[g2]
    t,p = stats.ttest_ind(x,y_,equal_var=False)
    rows.append({
        "grp_1":g1, "grp2":g2,
        "n1":x.size, "n2":y_.size,
        "mean_1":x.mean(), "mean_2":y_.mean(),
        "diff": x.mean() - y_.mean(),
        "t":t, "p_raw":p
    })

res=pd.DataFrame(rows)
res.head()

res["p_holm"]=multipletests(res["p_raw"],method="holm")[1]
# res["p_bonf"]=multipletests(res["p_raw"],method="bonferroni")[1]
res["sig_0.05_holm"]=res["p_holm"]<0.05

res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#         grp_1        grp2   n1   n2    mean_1    mean_2      diff         t  \
# 0         Yes  Don't know  477  408  0.639413  0.370098  0.269315  8.283015
# 1         Yes          No  477  374  0.639413  0.483957  0.155456  4.576329
# 2  Don't know          No  408  374  0.370098  0.483957 -0.113859 -3.230335
#
#           p_raw        p_holm  sig_0.05_holm
# 0  4.573974e-16  1.372192e-15           True
# 1  5.498166e-06  1.099633e-05           True
# 2  1.289054e-03  1.289054e-03           True

# %%
# import numpy as np
# import pandas as pd
# from itertools import combinations
# from scipy import stats
# from statsmodels.stats.multitest import multipletests

# # 0) Ensure the outcome is numeric 0/1 and drop NAs
# y = df["treat_bin"].astype(float)

# # 1) Build arrays per support group
# groups = {"Woman": g_w, "Man": g_m, "Trans_Non-binary_GNC": g_t_nb_gnc}

# # Optional: skip tiny groups
# # groups = {k:v for k,v in groups.items() if v.size >= 10}

# # 2) Pairwise Welch t-tests (safer than equal_var=True)
# rows = []
# for g1, g2 in combinations(groups, 2):
#     x, y_ = groups[g1], groups[g2]
#     t, p = stats.ttest_ind(x, y_, equal_var=False)
#     rows.append({
#         "grp1": g1, "grp2": g2,
#         "n1": x.size, "n2": y_.size,
#         "mean1": x.mean(), "mean2": y_.mean(),
#         "diff": x.mean() - y_.mean(),
#         "t": t, "p_raw": p
#     })

# res = pd.DataFrame(rows)

# # 3) Multiple-comparison correction (Holm and Bonferroni)
# res["p_bonf"] = multipletests(res["p_raw"], method="bonferroni")[1]
# res["p_holm"] = multipletests(res["p_raw"], method="holm")[1]
# res["sig_0.05_holm"] = res["p_holm"] < 0.05

# # 4) Nicely sorted view
# res = res.sort_values("p_holm").reset_index(drop=True)
# res

# %%
# # 1) Build arrays per support group
# groups = {}
# for s in sorted(df["support_score"].dropna().unique()):
#     groups[s] = y[df["support_score"].eq(s)].dropna().to_numpy()

# %% [markdown]
# #### <span style="color:pink"> 2. Do you know the options for mental health care your employer provides?</span>

# %%
care_options_map = {"Yes": "Yes", "No": "No", "Not sure": "Don't know"}
df["care_options_plt"] = df["care_options"].map(care_options_map)

df['care_options_plt'] = pd.Categorical(df['care_options_plt'],
                                categories=['Yes', 'No', "Don't know"],
                                ordered=True)

g = sns.histplot(data=df, x="care_options_plt", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Care options awareness") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Care options awareness vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
care_options_map = {"Yes": "Yes", "No": "No", "Not sure": "Don't know"}
df["care_options_plt"] = df["care_options"].map(care_options_map)

g = sns.barplot(data=df, x="care_options_plt", y="treat_bin", order=["Yes", "No", "Don't know"], palette="dark", hue="care_options_plt")
g.set(ylim=(0,1))
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("Care options awareness")
g.figure.suptitle("Care options awareness vs Treatment seeking rate")
plt.show()

# %%
#building a dictionary that holds the values of `care_options` variables as keys and corresponding `treat_bin` values as values
y = df["treat_bin"].astype(float)

groups={}
for care in (df['care_options_plt'].dropna().to_numpy()):
    groups[care]=y[df['care_options_plt'].eq(care)].dropna().to_numpy()

# print(groups)
rows=[]
for g1, g2 in combinations(groups, 2):
    x,y_=groups[g1],groups[g2]
    t,p=stats.ttest_ind(x,y_,equal_var=False)
    rows.append({
        "grp1":g1, "grp2":g2,
        "n1":x.size, "n2":y_.size,
        "mean_1":x.mean(), "mean_2":y_.mean(),
        "diff":x.mean() - y_.mean(),
        "t":t, "p_raw":p
    })

    # print(rows)

res=pd.DataFrame(rows)

res["p_holm"]=multipletests(res["p_raw"], method="holm")[1]
res["sig_0.05_holm"]=res["p_holm"]<0.05

res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#          grp1 grp2   n1   n2    mean_1    mean_2      diff         t  \
# 0          No  Yes  501  444  0.413174  0.691441 -0.278268 -8.950685
# 1  Don't know  Yes  314  444  0.391720  0.691441 -0.299722 -8.501704
# 2  Don't know   No  314  501  0.391720  0.413174 -0.021454 -0.607736
#
#           p_raw        p_holm  sig_0.05_holm
# 0  1.851703e-18  5.555108e-18           True
# 1  1.278290e-16  2.556580e-16           True
# 2  5.435688e-01  5.435688e-01          False

# %%
# keep a desired order
order = ["Yes", "No", "Don't know"]

# build tidy table with fixed column names
d = (df["care_options_plt"]
       .value_counts()
       .reindex(order, fill_value=0)
       .rename_axis("group")            # <-- set index name
       .reset_index(name="nb_people"))  # --> columns: ['group','nb_people']

# exact colors
color_map = {"Yes":"#2ca02c", "No":"#d62728", "Don't know":"#1f77b4"}
colors = [color_map[g] for g in d["group"]]

# plot
squarify.plot(
    sizes=d["nb_people"],
    label=d["group"],
    color=colors,
    alpha=.9,
    text_kwargs={"fontsize":12}
)

plt.axis("off")
plt.title("Do you know the options for mental \n health care your employer provides?",color="red", fontsize=14, fontweight="bold")
plt.show()

# %% [markdown]
# #### <span style="color:pink"> 3. Does your employer provide resources to learn more about mental health issues and how to seek help?</span>

# %%
print(df["seek_help"].unique())
print(sum(df["seek_help"].isna()))

df['seek_help'] = pd.Categorical(df['seek_help'],
                                categories=['Yes', 'No', "Don't know"],
                                ordered=True)

g = sns.histplot(data=df, x="seek_help", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Employer provides resources/instructions") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Employer provides resources/instructions vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()
# Out:
# ['Yes' "Don't know" 'No']
# 0

# %%
g = sns.barplot(data=df, x="seek_help", y="treat_bin", order=["Yes", "No", "Don't know"], palette="Spectral", hue="seek_help")
g.set(ylim=(0,1))
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("Employer provides resources and instructions")
g.figure.suptitle("Employer provides resources/instructions vs Treatment seeking rate")
plt.show()

# %%
#building a dictionary that holds the values of `care_options` variables as keys and corresponding `treat_bin` values as values
y = df["treat_bin"].astype(float)

groups={}
for seek in (df['seek_help'].dropna().to_numpy()):
    groups[seek]=y[df['seek_help'].eq(seek)].dropna().to_numpy()

# print(groups)
rows=[]
for g1, g2 in combinations(groups, 2):
    x,y_=groups[g1],groups[g2]
    t,p=stats.ttest_ind(x,y_,equal_var=False)
    rows.append({
        "grp1":g1, "grp2":g2,
        "n1":x.size, "n2":y_.size,
        "mean_1":x.mean(), "mean_2":y_.mean(),
        "diff":x.mean() - y_.mean(),
        "t":t, "p_raw":p
    })

    # print(rows)

res=pd.DataFrame(rows)

res["p_holm"]=multipletests(res["p_raw"], method="holm")[1]
res["sig_0.05_holm"]=res["p_holm"]<0.05

res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#          grp1        grp2   n1   n2  mean_1  mean_2    diff         t  \
# 0         Yes  Don't know  250  363  0.5920  0.4573  0.1347  3.310470
# 1         Yes          No  250  646  0.5920  0.5000  0.0920  2.496885
# 2  Don't know          No  363  646  0.4573  0.5000 -0.0427 -1.303441
#
#       p_raw    p_holm  sig_0.05_holm
# 0  0.000994  0.002981           True
# 1  0.012878  0.025756           True
# 2  0.192823  0.192823          False

# %%
# keep a desired order
order = ["Yes", "No", "Don't know"]

# build tidy table with fixed column names
d = (df["seek_help"]
       .value_counts()
       .reindex(order, fill_value=0)
       .rename_axis("group")            # <-- set index name
       .reset_index(name="nb_people"))  # --> columns: ['group','nb_people']

# exact colors
color_map = {"Yes":"#2ca02c", "No":"#d62728", "Don't know":"#1f77b4"}
colors = [color_map[g] for g in d["group"]]

# plot
squarify.plot(
    sizes=d["nb_people"],
    label=d["group"],
    color=colors,
    alpha=.9,
    text_kwargs={"fontsize":12}
)

plt.axis("off")
plt.title("Does your employer provide resources to learn more\n about mental health issues and how to seek help?",color="red", fontsize=14, fontweight="bold")
plt.show()

# %% [markdown]
# #### <span style="color:pink"> 4. Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?</span>

# %%
df['anonymity'] = pd.Categorical(df['anonymity'],
                                categories=['Yes', 'No', "Don't know"],
                                ordered=True)

g = sns.histplot(data=df, x="anonymity", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Anonymity protected if resources used") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Anonymity protected if resources used vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
print(df["anonymity"].unique())
print(sum(df["anonymity"].isna()))

g = sns.barplot(data=df, x="anonymity", y="treat_bin", order=["Yes", "No", "Don't know"], palette="icefire", hue="anonymity")
g.set(ylim=(0,1))
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("Anonymity protection")
g.figure.suptitle("Anonymity protection vs Treatment seeking rate")
plt.show()
# Out:
# ['Yes', 'Don't know', 'No']
# Categories (3, object): ['Yes' < 'No' < 'Don't know']
# 0

# %%
#building a dictionary that holds the values of `care_options` variables as keys and corresponding `treat_bin` values as values
y = df["treat_bin"].astype(float)

groups={}
for seek in (df['anonymity'].dropna().to_numpy()):
    groups[seek]=y[df['anonymity'].eq(seek)].dropna().to_numpy()

# print(groups)
rows=[]
for g1, g2 in combinations(groups, 2):
    x,y_=groups[g1],groups[g2]
    t,p=stats.ttest_ind(x,y_,equal_var=False)
    rows.append({
        "grp1":g1, "grp2":g2,
        "n1":x.size, "n2":y_.size,
        "mean_1":x.mean(), "mean_2":y_.mean(),
        "diff":x.mean() - y_.mean(),
        "t":t, "p_raw":p
    })

    # print(rows)

res=pd.DataFrame(rows)

res["p_holm"]=multipletests(res["p_raw"], method="holm")[1]
res["sig_0.05_holm"]=res["p_holm"]<0.05

res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#          grp1        grp2   n1   n2    mean_1    mean_2      diff         t  \
# 0         Yes  Don't know  375  819  0.608000  0.452991  0.155009  5.055326
# 1  Don't know          No  819   65  0.452991  0.584615 -0.131624 -2.056297
# 2         Yes          No  375   65  0.608000  0.584615  0.023385  0.351276
#
#           p_raw    p_holm  sig_0.05_holm
# 0  5.424336e-07  0.000002           True
# 1  4.325253e-02  0.086505          False
# 2  7.262320e-01  0.726232          False

# %%
# keep a desired order
order = ["Yes", "No", "Don't know"]

# build tidy table with fixed column names
d = (df["anonymity"]
       .value_counts()
       .reindex(order, fill_value=0)
       .rename_axis("group")            # <-- set index name
       .reset_index(name="nb_people"))  # --> columns: ['group','nb_people']

# exact colors
color_map = {"Yes":"#2ca02c", "No":"#d62728", "Don't know":"#1f77b4"}
colors = [color_map[g] for g in d["group"]]

# plot
squarify.plot(
    sizes=d["nb_people"],
    label=d["group"],
    color=colors,
    alpha=.9,
    text_kwargs={"fontsize":12}
)

plt.axis("off")
plt.title("Is your anonymity protected if you choose to take advantage of \nmental health or substance abuse treatment resources?",color="red", fontsize=14, fontweight="bold")
plt.show()

# %% [markdown]
# #### <span style="color:pink"> 5. Has your employer ever discussed mental health as part of an employee wellness program?</span>

# %%
df['wellness_program'] = pd.Categorical(df['wellness_program'],
                                categories=['Yes', 'No', "Don't know"],
                                ordered=True)

g = sns.histplot(data=df, x="wellness_program", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Employer discusses mental health") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Employer discusses mental health vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
print(df["wellness_program"].unique())
print(sum(df["wellness_program"].isna()))

g = sns.barplot(data=df, x="wellness_program", y="treat_bin", order=["Yes", "No", "Don't know"], palette="magma", hue="wellness_program")
g.set(ylim=(0,1))
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("Employer discuss mental health")
g.figure.suptitle("Employer discuss mental health vs Treatment seeking rate")
plt.show()
# Out:
# ['No', 'Don't know', 'Yes']
# Categories (3, object): ['Yes' < 'No' < 'Don't know']
# 0

# %%
#building a dictionary that holds the values of `care_options` variables as keys and corresponding `treat_bin` values as values
y = df["treat_bin"].astype(float)

groups={}
for seek in (df['wellness_program'].dropna().to_numpy()):
    groups[seek]=y[df['wellness_program'].eq(seek)].dropna().to_numpy()

# print(groups)
rows=[]
for g1, g2 in combinations(groups, 2):
    x,y_=groups[g1],groups[g2]
    t,p=stats.ttest_ind(x,y_,equal_var=False)
    rows.append({
        "grp1":g1, "grp2":g2,
        "n1":x.size, "n2":y_.size,
        "mean_1":x.mean(), "mean_2":y_.mean(),
        "diff":x.mean() - y_.mean(),
        "t":t, "p_raw":p
    })

    # print(rows)

res=pd.DataFrame(rows)

res["p_holm"]=multipletests(res["p_raw"], method="holm")[1]
res["sig_0.05_holm"]=res["p_holm"]<0.05

res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#          grp1        grp2   n1   n2    mean_1    mean_2      diff         t  \
# 0  Don't know         Yes  188  229  0.430851  0.593886 -0.163035 -3.349537
# 1          No         Yes  842  229  0.498812  0.593886 -0.095074 -2.582722
# 2          No  Don't know  842  188  0.498812  0.430851  0.067961  1.694489
#
#       p_raw    p_holm  sig_0.05_holm
# 0  0.000887  0.002660           True
# 1  0.010190  0.020379           True
# 2  0.091291  0.091291          False

# %%
# keep a desired order
order = ["Yes", "No", "Don't know"]

# build tidy table with fixed column names
d = (df["wellness_program"]
       .value_counts()
       .reindex(order, fill_value=0)
       .rename_axis("group")            # <-- set index name
       .reset_index(name="nb_people"))  # --> columns: ['group','nb_people']

# exact colors
color_map = {"Yes":"#2ca02c", "No":"#d62728", "Don't know":"#1f77b4"}
colors = [color_map[g] for g in d["group"]]

# plot
squarify.plot(
    sizes=d["nb_people"],
    label=d["group"],
    color=colors,
    alpha=.9,
    text_kwargs={"fontsize":12}
)

plt.axis("off")
plt.title("Has your employer ever discussed mental health \nas part of an employee wellness program?",color="red", fontsize=14, fontweight="bold")
plt.show()

# %% [markdown]
# ### <span style="color:lightgreen"> Summary of support score components</span>

# %% [markdown]
#     * `benefits`: Does your employer provide mental health benefits?
#     * `care_options`: Do you know the options for mental health care your employer provides?
#     * `seek_help`: Does your employer provide resources to learn more about mental health issues and how to seek help?
#     * `anonymity`: Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources?
#     * `wellness_program`: Has your employer ever discussed mental health as part of an employee wellness program?

# %%
qs = {
    "benefits": "Does your employer provide mental health benefits?",
    "care_options_plt": "Do you know the options for mental health care \nyour employer provides?",
    "seek_help": "Does your employer provide resources to learn more \nabout mental health issues and how to seek help?",
    "anonymity": "Is your anonymity protected if you choose to take advantage \nof mental health or substance abuse treatment resources?",
    "wellness_program": "Has your employer ever discussed mental\n health as part of an employee wellness program?",
}
order = ["Yes", "No", "Don't know"]
colors = {"Yes":"#64E987", "No":"#FF99A9", "Don't know":"#88CEFB"}

# Build proportions table
prop_rows = []
for col, label in qs.items():
    s = df[col].value_counts(normalize=True).reindex(order, fill_value=0)
    s.name = label
    prop_rows.append(s)
props = pd.DataFrame(prop_rows)

# Plot as 100% stacked bars
fig, ax = plt.subplots(figsize=(8, 4))
left = 0
for cat in order:
    ax.barh(props.index, props[cat], left=left, color=colors[cat], label=cat)
    left += props[cat]

# Format
ax.set_xlim(0, 1)
ax.set_xlabel("Proportion")
ax.set_ylabel("")
ax.invert_yaxis()  # most important at top
ax.legend(loc="lower right", ncol=3, frameon=False)
ax.grid(axis="x", ls=":", alpha=.3)
fig.figure.suptitle("Mental health support metrics")

# grab legend entries from the axes
handles, labels = ax.get_legend_handles_labels()

# remove the axis legend
if ax.get_legend() is not None:
    ax.get_legend().remove()

# add a figure-level legend bottom-left
fig = ax.get_figure()
fig.legend(handles, labels,
           loc="lower left",            # anchor corner of the legend box
           bbox_to_anchor=(-0.35, 0.01), # figure coords: (0,0)=bottom-left
           ncol=3, frameon=False, title=None)

# make room for it
fig.subplots_adjust(bottom=0.15)               # squeeze layout

plt.show()

# %% [markdown]
# ### <span style="color:orange"> Support score vs. Treatment rate</span>

# %%
# Add 0/1 for treatment: `treat_bin` to `df`
df["treat_bin"] = df["treatment"].str.strip().str.casefold().map({"yes":1,"no":0}).astype("Int64")

# 1) Overall: Support → Treatment (95% CI)
g = sns.pointplot(
    data=df, x="support_score", y="treat_bin",
    estimator=np.mean, errorbar=("ci", 95), dodge=False,
    color="darkblue"    
)
g.set(xlabel="Support score (0–5)", ylabel="Treatment seeking rate", ylim=(0, 1),
       title="Support → Treatment seeking rate (95% CI)")
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <b>Insight:</b>
#
# * There is a clear positive association between perceived support and treatment seeking.
#
# * Employees who report more visible/accessible support policies are substantially more likely to seek treatment, with gains up to about support=3 and a plateau thereafter
#
# </div>

# %% [markdown]
# #### <span style="color:orange"> Support score vs. Treatment rate</span>: <span style="color:pink">by Company Size</span>

# %% [markdown]
# <span style="color:lightgreen">Support score with original company size breakdown</span>

# %%
g = sns.pointplot(data=df, x="company_size_cat", y="support_score")
g.set(ylim=(0,5))
plt.show()

# %% [markdown]
# <div class="alert alert-danger" style="color: blue;">
#   Make a new company size variable that bins the company sizes as the following: <=25, 26-100, 101-500, >500. Then replot these plots with the new company size variable.
# </div>

# %% [markdown]
# <span style="color:lightgreen">Support score with 3-category company size variable</span>

# %%
g = sns.pointplot(data=df, x="company_size_cat2", y="support_score")
g.set(ylim=(0,5))
g.set(ylabel="Support score (0–5)", xlabel="Company size", title="Company size vs Support score")
plt.show()

# %% [markdown]
# <span style="color:lightblue">Treatment seeking rate with 3-category company size variable</span>

# %%
g = sns.pointplot(data=df, x="company_size_cat2", y="treat_bin")
g.set(ylim=(0,1))
g.set(ylabel="Treatment seeking rate", xlabel="Company size", title="Company size vs Treatment seeking rate")
plt.show()

# %% [markdown]
# <span style="color:lightblue">Work interference severity with 3-category company size variable</span>

# %%
g = sns.pointplot(data=df, x="company_size_cat2", y="work_interfere_sev")
g.set(ylim=(0,3))
g.set(ylabel="Work interference severity (0–3)", xlabel="Company size", title="Company size vs Work interference severity")
plt.show()

# %% [markdown]
# <span style="color:lightgreen">Support score vs. Treatment score (by Company size)</span>

# %%
# 2) Small multiples by company size
g = sns.catplot(
    data=df, x="support_score", y="treat_bin",
    row="company_size_cat2", kind="point",
    estimator=np.mean, errorbar=("ci", 95), dodge=False,
    height=3.5, aspect=1.5,
    color="red"
)

g.set_axis_labels("Support score (0–5)", "Treatment seeking rate")
g.set(ylim=(0, 1))
g.set_titles(row_template="{row_name}")

fig = g.figure

fig.suptitle("Support → Treatment seeking rate (95% CI) by Company Size", fontsize=14)

fig.tight_layout()
fig.subplots_adjust(bottom=0, top=.92, left=0.08, right=0.98)  # margins
fig.subplots_adjust(wspace=0.25, hspace=0.35) # spacing between facets


plt.show()

# %% [markdown]
# #### <span style="color:orange"> Support score vs. Treatment rate</span>: <span style="color:pink">by Gender</span>

# %%
df["gender_2"] = df["gender_3"].where(df["gender_3"].isin(["Woman", "Man"]), pd.NA)

df["gender_2"] = df["gender_2"].astype(CategoricalDtype(categories=["Woman", "Man"], ordered=False))

#Sanity check
print(df["gender_2"].value_counts(dropna=False))

g = sns.catplot(
    data=df,
    x="support_score", y="treat_bin",
    col="gender_2",
    kind="point",
    estimator=np.mean, errorbar=("ci", 95),
    order=[0,1,2,3,4,5], dodge=False,
    height=4, aspect=1.0, sharey=True
)
g.set_axis_labels("Support score (0–5)", "Treatment seeking rate")
g.set(ylim=(0, 1))  
g.set_titles("{col_name}")
plt.show()
# Out:
# gender_2
# Man      993
# Woman    251
# NaN       15
# Name: count, dtype: int64

# %% [markdown]
# #### <span style="color:orange">`gender_*`: Gender vs. Treatment rate</span>

# %%
print(df["gender_3"].value_counts(dropna=False))
sns.pointplot(data=df, x="gender_3", y="treat_bin", estimator=np.mean, errorbar=("ci", 95), dodge=False)
plt.show()
# Out:
# gender_3
# Man               993
# Woman             251
# Non-binary_GNC     10
# Unknown/Other       5
# Name: count, dtype: int64

# %%
g = sns.histplot(data=df, x="gender_2", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Gender") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Gender vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
g = sns.barplot(data=df, x="gender_2", y="treat_bin", estimator=np.mean, errorbar=("ci", 95), dodge=False, palette="tab10", hue="gender_2", legend=False)
g.set(ylim=(0, 1)) 
g.set_xlabel("Gender")
g.set_ylabel("Treatment seeking rate")
g.figure.suptitle("Treatment seeking rate vs Gender")
plt.show()

# %% [markdown]
# ***<span style="color:pink">Optional statistical A/B test for gender vs treatment rate</span>***

# %%
import numpy as np
from scipy import stats

# two masks
w_mask = df["gender_2"].eq("Woman")
m_mask = df["gender_2"].eq("Man")

# pull the binary outcome; drop missing, make numeric arrays
g_w = df.loc[w_mask, "treat_bin"].dropna().astype(float).to_numpy()
g_m = df.loc[m_mask, "treat_bin"].dropna().astype(float).to_numpy()

alpha = 0.05

# Welch’s t-test (safer with unequal variances)
t_stat, p_val = stats.ttest_ind(g_w, g_m, equal_var=False)

print(f"n_women={g_w.size}, n_men={g_m.size}")
print(f"mean_women={g_w.mean():.3f}, mean_men={g_m.mean():.3f}, diff={g_w.mean()-g_m.mean():.3f}")
print(f"t={t_stat:.3f}, p={p_val:.6f}")

if p_val < alpha:
    print("Reject H0: groups differ.")
else:
    print("Fail to reject H0: no evidence of a difference.")
# Out:
# n_women=251, n_men=993
# mean_women=0.689, mean_men=0.455, diff=0.234
# t=7.036, p=0.000000
# Reject H0: groups differ.

# %%
print(np.var(g_w))
print(np.var(g_m))
# Out:
# 0.21418707639561282
# 0.24799173266237273

# %%
keep = ["Woman", "Man", "Trans_Non-binary_GNC"]
df_plot = df[df["gender_3_alt"].isin(keep)]

g = sns.histplot(data=df_plot, x="gender_3_alt", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Gender") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Gender vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
g = sns.barplot(data=df_plot, x="gender_3_alt", y="treat_bin", estimator=np.mean, errorbar=("ci", 95), dodge=False, palette="tab10", hue="gender_3_alt", legend=False)
g.set(ylim=(0, 1)) 
g.set_xlabel("Gender")
g.set_ylabel("Treatment seeking rate")
g.figure.suptitle("Treatment seeking rate vs Gender")
plt.show()

# %%
# two masks
w_mask = df["gender_3_alt"].eq("Woman")
m_mask = df["gender_3_alt"].eq("Man")
t_nb_gnc_mask = df["gender_3_alt"].eq("Trans_Non-binary_GNC")

# pull the binary outcome; drop missing, make numeric arrays
g_w = df.loc[w_mask, "treat_bin"].dropna().astype(float).to_numpy()
g_m = df.loc[m_mask, "treat_bin"].dropna().astype(float).to_numpy()
g_t_nb_gnc = df.loc[t_nb_gnc_mask, "treat_bin"].dropna().astype(float).to_numpy()

alpha = 0.05

# Welch's One-way ANOVA 
f_stat, p_val = stats.f_oneway(g_w, g_m, g_t_nb_gnc, equal_var=False)

print(f"n_woman={g_w.size}, n_man={g_m.size}, n_trans_nb_gnc={g_t_nb_gnc.size}")
print(f"mean_woman={g_w.mean():.3f}, mean_man={g_m.mean():.3f}, mean_trans_nb_gnc={g_t_nb_gnc.mean():.3f}")
print(f"f={f_stat:.3f}, p={p_val:.6f}")

if p_val < alpha:
    print("Reject H0: groups differ.")
else:
    print("Fail to reject H0: no evidence of a difference.")
# Out:
# n_woman=247, n_man=993, n_trans_nb_gnc=14
# mean_woman=0.688, mean_man=0.455, mean_trans_nb_gnc=0.714
# f=25.068, p=0.000000
# Reject H0: groups differ.

# %%
import numpy as np
import pandas as pd
from itertools import combinations
from scipy import stats
from statsmodels.stats.multitest import multipletests

# 0) Ensure the outcome is numeric 0/1 and drop NAs
y = df["treat_bin"].astype(float)

# 1) Build arrays per support group
groups = {"Woman": g_w, "Man": g_m, "Trans_Non-binary_GNC": g_t_nb_gnc}

# Optional: skip tiny groups
# groups = {k:v for k,v in groups.items() if v.size >= 10}

# 2) Pairwise Welch t-tests (safer than equal_var=True)
rows = []
for g1, g2 in combinations(groups, 2):
    x, y_ = groups[g1], groups[g2]
    t, p = stats.ttest_ind(x, y_, equal_var=False)
    rows.append({
        "grp1": g1, "grp2": g2,
        "n1": x.size, "n2": y_.size,
        "mean1": x.mean(), "mean2": y_.mean(),
        "diff": x.mean() - y_.mean(),
        "t": t, "p_raw": p
    })

res = pd.DataFrame(rows)

# 3) Multiple-comparison correction (Holm and Bonferroni)
# res["p_bonf"] = multipletests(res["p_raw"], method="bonferroni")[1]
res["p_holm"] = multipletests(res["p_raw"], method="holm")[1]
res["sig_0.05_holm"] = res["p_holm"] < 0.05

# 4) Nicely sorted view
res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#     grp1                  grp2   n1   n2     mean1     mean2      diff  \
# 0  Woman                   Man  247  993  0.688259  0.455186  0.233073
# 1    Man  Trans_Non-binary_GNC  993   14  0.455186  0.714286 -0.259099
# 2  Woman  Trans_Non-binary_GNC  247   14  0.688259  0.714286 -0.026027
#
#           t         p_raw        p_holm  sig_0.05_holm
# 0  6.957612  1.425759e-11  4.277278e-11           True
# 1 -2.051660  6.025341e-02  1.205068e-01          False
# 2 -0.202184  8.425859e-01  8.425859e-01          False

# %% [markdown]
# ### <span style="color:orange">`us_category`: Counts</span>

# %%
g = sns.catplot(x=df["us_category"].cat.remove_unused_categories(), data=df, kind="count", palette="pastel", hue="us_category")
g.figure.suptitle("Country", y=1.04)
g.set_ylabels("Count")
g.set_xlabels("")
plt.show()

# %% [markdown]
# ### <span style="color:orange">`us_category`: Treatment rate</span>

# %%
# Add 0/1 for treatment: `treat_bin` to `df`
df["treat_bin"] = df["treatment"].str.strip().str.casefold().map({"yes":1,"no":0}).astype("Int64")

g = sns.histplot(data=df, x="us_category", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("US/non-USA") 
g.set_ylabel("Number of employees")
g.figure.suptitle("US/non-USA vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
g = sns.barplot(data=df, y="treat_bin", x=df["us_category"].cat.remove_unused_categories(), palette="gnuplot2", hue=df["us_category"].cat.remove_unused_categories())
g.figure.suptitle("US or Non-US vs. Treatment seeking rate")
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("")
g.set(ylim=(0,1))
plt.show()

# %%
df["us_category"].unique()
# Out:
# ['US', 'Non-US']
# Categories (3, object): ['US', 'Non-US', 'Unknown']

# %%
# two masks
us_mask = df["us_category"].eq("US")
non_us_mask = df["us_category"].eq("Non-US")

# pull the binary outcome; drop missing, make numeric arrays
g_us = df.loc[us_mask, "treat_bin"].dropna().astype(float).to_numpy()
g_non_us = df.loc[non_us_mask, "treat_bin"].dropna().astype(float).to_numpy()

alpha = 0.05

# Welch’s t-test (safer with unequal variances)
t_stat, p_val = stats.ttest_ind(g_us, g_non_us, equal_var=False)

print(f"n_us={g_us.size}, n_non_us={g_non_us.size}")
print(f"mean_us={g_w.mean():.3f}, mean_non_us={g_m.mean():.3f}, diff={g_us.mean()-g_non_us.mean():.3f}")
print(f"t={t_stat:.3f}, p={p_val:.6f}")

if p_val < alpha:
    print("Reject H0: groups differ.")
else:
    print("Fail to reject H0: no evidence of a difference.")
# Out:
# n_us=751, n_non_us=508
# mean_us=0.688, mean_non_us=0.455, diff=0.099
# t=3.464, p=0.000552
# Reject H0: groups differ.

# %%
print(np.var(g_us))
print(np.var(g_non_us))
# Out:
# 0.24788963140136278
# 0.2471751193502387

# %% [markdown]
# ### <span style="color:orange">Creating `region` for US states: Region vs. Treatment rate</span>

# %%
# Make an explicit copy to avoid view-vs-copy ambiguity
df_us = df.loc[df["us_category"] == "US", :].copy()

df_us["state"].unique()

northeast = {'CT','ME','MA','NH','NJ','NY','PA','RI','VT'}
midwest   = {'IL','IN','IA','KS','MI','MN','MO','NE','ND','OH','SD','WI'}
south     = {'AL','AR','DC','DE','FL','GA','KY','LA','MD','MS','NC','SC','TN','VA','WV'}
southwest = {'AZ','NM','OK','TX'}
west      = {'CA','CO','ID','MT','NV','OR','UT','WA','WY','AK','HI'}

region_map = {}
region_map.update({s: 'Northeast' for s in northeast})
region_map.update({s: 'Midwest'   for s in midwest})
region_map.update({s: 'South'     for s in south})
region_map.update({s: 'Southwest' for s in southwest})
region_map.update({s: 'West'      for s in west})

df_us['region'] = df_us['state'].map(region_map).fillna("Unknown")

order = ['Northeast', 'Midwest', 'South', 'Southwest', 'West', 'Unknown']

df_us["region"] = df_us["region"].astype(CategoricalDtype(categories=order, ordered=True))

# %%
df_us.groupby("state")["treat_bin"].mean().reset_index(name="treatment_seeking_rate").sort_values("treatment_seeking_rate", ascending=False)
# Out:
#    state  treatment_seeking_rate
# 21    MS                     1.0
# 9     ID                     1.0
# 17    ME                     1.0
# 14    LA                     1.0
# 0     AL                   0.875
# 1     AZ                0.857143
# 42    WI                    0.75
# 8     IA                    0.75
# 10    IL                0.678571
# 24    NH                0.666667
# 29    OH                0.666667
# 27    NV                0.666667
# 2     CA                0.623188
# 38    UT                     0.6
# 31    OR                0.586207
# 41    WA                0.585714
# 19    MN                0.571429
# 37    TX                0.568182
# 28    NY                0.535714
# 6     FL                0.533333
# 25    NJ                     0.5
# 23    NE                     0.5
# 22    NC                     0.5
# 44    WY                     0.5
# 4     CT                     0.5
# 15    MA                     0.5
# 7     GA                     0.5
# ...

# %%
df_us.groupby("region", observed=True)["treat_bin"].mean().reset_index(name="treatment_seeking_rate").sort_values("treatment_seeking_rate", ascending=False)
# Out:
#       region  treatment_seeking_rate
# 4       West                0.603053
# 1    Midwest                0.560976
# 3  Southwest                0.559322
# 0  Northeast                0.504065
# 2      South                0.454545
# 5    Unknown                0.454545

# %%
df_us.groupby("state", observed=True)["treat_bin"].value_counts().reset_index()
# Out:
#    state  treat_bin  count
# 0     AL          1      7
# 1     AL          0      1
# 2     AZ          1      6
# 3     AZ          0      1
# 4     CA          1     86
# ..   ...        ...    ...
# 76    WI          1      9
# 77    WI          0      3
# 78    WV          0      1
# 79    WY          0      1
# 80    WY          1      1
#
# [81 rows x 3 columns]

# %%
df_us.groupby("region", observed=True)["treat_bin"].value_counts().reset_index(name="counts")
# Out:
#        region  treat_bin  counts
# 0   Northeast          1      62
# 1   Northeast          0      61
# 2     Midwest          1      92
# 3     Midwest          0      72
# 4       South          0      72
# 5       South          1      60
# 6   Southwest          1      33
# 7   Southwest          0      26
# 8        West          1     158
# 9        West          0     104
# 10    Unknown          0       6
# 11    Unknown          1       5

# %%
df_us.groupby("region", observed=True)["treatment"].value_counts().reset_index(name="counts")
# Out:
#        region treatment  counts
# 0   Northeast       Yes      62
# 1   Northeast        No      61
# 2     Midwest       Yes      92
# 3     Midwest        No      72
# 4       South        No      72
# 5       South       Yes      60
# 6   Southwest       Yes      33
# 7   Southwest        No      26
# 8        West       Yes     158
# 9        West        No     104
# 10    Unknown        No       6
# 11    Unknown       Yes       5

# %%
g = sns.histplot(data=df_us, x="region", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("US/non-USA") 
g.set_ylabel("Number of employees")
g.figure.suptitle("US regions vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
g = sns.barplot(data=df_us, y="treat_bin", x="region", palette="gnuplot2", hue="region")
g.figure.suptitle("US regions vs. Treatment seeking rate")
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("")
g.set(ylim=(0,1))
plt.show()

# %%
# two masks
ne_mask = df_us["region"].eq("Northeast")
mw_mask = df_us["region"].eq("Midwest")
s_mask = df_us["region"].eq("South")
sw_mask = df_us["region"].eq("Southwest")
w_mask = df_us["region"].eq("West")

# pull the binary outcome; drop missing, make numeric arrays
g_ne = df_us.loc[ne_mask, "treat_bin"].dropna().astype(float).to_numpy()
g_mw = df_us.loc[mw_mask, "treat_bin"].dropna().astype(float).to_numpy()
g_s = df_us.loc[s_mask, "treat_bin"].dropna().astype(float).to_numpy()
g_sw = df_us.loc[sw_mask, "treat_bin"].dropna().astype(float).to_numpy()
g_w = df_us.loc[w_mask, "treat_bin"].dropna().astype(float).to_numpy()

alpha = 0.05

# Welch's One-way ANOVA 
f_stat, p_val = stats.f_oneway(g_ne, g_mw, g_s, g_sw, g_w, equal_var=False)

print(f"n_ne={g_ne.size}, n_mw={g_mw.size}, n_s={g_s.size}, n_sw={g_sw.size}, n_w={g_w.size}")
print(f"mean_ne={g_ne.mean():.3f}, mean_mw={g_mw.mean():.3f}, mean_s={g_s.mean():.3f},mean_sw={g_sw.mean():.3f}, mean_w={g_w.mean():.3f}")
print(f"f={f_stat:.3f}, p={p_val:.6f}")

if p_val < alpha:
    print("Reject H0: groups differ.")
else:
    print("Fail to reject H0: no evidence of a difference.")
# Out:
# n_ne=123, n_mw=164, n_s=132, n_sw=59, n_w=262
# mean_ne=0.504, mean_mw=0.561, mean_s=0.455,mean_sw=0.559, mean_w=0.603
# f=2.233, p=0.065838
# Fail to reject H0: no evidence of a difference.

# %% [markdown]
# ***<span style="color:pink">Optional statistical A/B test for us_category vs treatment rate</span>***

# %%
# import numpy as np
# from scipy import stats

# # two masks
# us_mask = df["us_category"].eq("US")
# non_us_mask = df["us_category"].eq("Non-US")

# # pull the binary outcome; drop missing, make numeric arrays
# g_us_mask = df.loc[us_mask, "treat_bin"].dropna().astype(float).to_numpy()
# g_non_us_mask = df.loc[non_us_mask, "treat_bin"].dropna().astype(float).to_numpy()

# alpha = 0.05

# # Welch’s t-test (safer with unequal variances)
# t_stat, p_val = stats.ttest_ind(g_us_mask, g_non_us_mask, equal_var=False)

# print(f"n_women={g_us_mask.size}, n_men={g_non_us_mask.size}")
# print(f"mean_women={g_us_mask.mean():.3f}, mean_men={g_non_us_mask.mean():.3f}, diff={g_us_mask.mean()-g_non_us_mask.mean():.3f}")
# print(f"t={t_stat:.3f}, p={p_val:.6f}")

# if p_val < alpha:
#     print("Reject H0: groups differ.")
# else:
#     print("Fail to reject H0: no evidence of a difference.")

# %%
# # barplot of mean treatment rate with 95% CI
# g = sns.barplot(data=df, x="gender_2", y="treat_bin",
#                  estimator=np.mean, errorbar=("ci", 95), dodge=False, palette="tab10", hue="gender_2", legend=False)
# g.set(ylim=(0,1), xlabel="Gender", ylabel="Treatment rate")

# # compose one string with newlines
# note = (
#     f"n_women={g_w.size}, n_men={g_m.size}\n"
#     f"mean_women={g_w.mean():.3f}, mean_men={g_m.mean():.3f}, diff={g_w.mean()-g_m.mean():.3f}\n"
#     f"t_stat={t_stat:.3f}, p={p_val:.3g} → {'Reject H0' if p_val < 0.05 else 'Fail to reject H0'}"
# )

# # put it in the top-left of the axes
# g.text(0.02, 0.98, note, transform=g.transAxes, ha="left", va="top",
#         bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.9))

# plt.show()

# %% [markdown]
# #### <span style="color:orange">`age_*`: Age vs. Treatment rate</span>

# %%
df["age_cat"].value_counts()
g = sns.pointplot(data=df, x="age_cat", y="treat_bin", estimator=np.mean, errorbar=("ci", 95), dodge=False)
g.set(ylim=(0, 1)) 
g.set_xlabel("Age band")
g.set_ylabel("Treatment seeking rate")
plt.show()

# %%
df["age_cat_2"] = df["age_cat"].where(df["age_cat"].isin(["<25", "25–34", "35–44", "45+"]), pd.NA)

df["age_cat_2"] = df["age_cat_2"].astype(CategoricalDtype(categories=["<25", "25–34", "35–44", "45+"], ordered=True))

g = sns.pointplot(data=df, x="age_cat_2", y="treat_bin", estimator=np.mean, errorbar=("ci", 95), dodge=False, color="darkblue")

g.set(ylim=(0, 1), title="Age vs Treatment seeking rate") 
g.set_xlabel("Age band")
g.set_ylabel("Treatment seeking rate")
plt.show()

# %% [markdown]
# #### <span style="color:orange">`age_*`: Age vs. Treatment rate:</span> <span style="color:pink"> by Gender </span>

# %%
print(df["age_cat_2"].value_counts())
print(sum(df["age_cat_2"].isna()))

g = sns.catplot(
    data=df,
    x="age_cat_2", y="treat_bin",
    row="gender_2",
    kind="point",
    estimator=np.mean, errorbar=("ci", 95),
    order=["<25", "25–34", "35–44", "45+"], dodge=False,
    height=4, aspect=1.0, sharey=True, color="red"
)
g.set_axis_labels("Age band", "Treatment seeking rate")
g.set(ylim=(0, 1))  
g.set_titles("{row_name}")
plt.show()
# Out:
# age_cat_2
# 25–34    707
# 35–44    320
# <25      156
# 45+       68
# Name: count, dtype: int64
# 8

# %%
df["age_cat_2"].value_counts()
# Out:
# age_cat_2
# 25–34    707
# 35–44    320
# <25      156
# 45+       68
# Name: count, dtype: int64

# %%
df["age_cat_2"].unique()
# Out:
# ['35–44', '25–34', '<25', '45+', NaN]
# Categories (4, object): ['<25' < '25–34' < '35–44' < '45+']

# %%
# two masks
mask_25 = df["age_cat_2"].eq("<25")
mask_2534 = df["age_cat_2"].eq("25–34")
mask_3544 = df["age_cat_2"].eq("35–44")
mask_45 = df["age_cat_2"].eq("45+")

# pull the binary outcome; drop missing, make numeric arrays
g_25 = df.loc[mask_25, "treat_bin"].dropna().astype(float).to_numpy()
g_2534 = df.loc[mask_2534, "treat_bin"].dropna().astype(float).to_numpy()
g_3544 = df.loc[mask_3544, "treat_bin"].dropna().astype(float).to_numpy()
g_45 = df.loc[mask_45, "treat_bin"].dropna().astype(float).to_numpy()

alpha = 0.05

# Welch's One-way ANOVA 
f_stat, p_val = stats.f_oneway(g_25, g_2534, g_3544, g_45, equal_var=False)

print(f"n_25={g_25.size}, n_25_34={g_2534.size}, n_35_44={g_3544.size}, n_45={g_45.size}")
print(f"mean_25={g_25.mean():.3f}, mean_25_34={g_2534.mean():.3f}, mean_35_44={g_3544.mean():.3f}, mean_45={g_45.mean():.3f}")
print(f"f={f_stat:.3f}, p={p_val:.6f}")

if p_val < alpha:
    print("Reject H0: groups differ.")
else:
    print("Fail to reject H0: no evidence of a difference.")
# Out:
# n_25=156, n_25_34=707, n_35_44=320, n_45=68
# mean_25=0.449, mean_25_34=0.489, mean_35_44=0.547, mean_45=0.603
# f=2.524, p=0.058216
# Fail to reject H0: no evidence of a difference.

# %%
#building a dictionary that holds the values of `care_options` variables as keys and corresponding `treat_bin` values as values
y = df["treat_bin"].astype(float)

groups={}
for ages in (df['age_cat_2'].dropna().to_numpy()):
    groups[ages]=y[df['age_cat_2'].eq(ages)].dropna().to_numpy()

# print(groups)
rows=[]
for g1, g2 in combinations(groups, 2):
    x,y_=groups[g1],groups[g2]
    t,p=stats.ttest_ind(x,y_,equal_var=False)
    rows.append({
        "grp1":g1, "grp2":g2,
        "n1":x.size, "n2":y_.size,
        "mean_1":x.mean(), "mean_2":y_.mean(),
        "diff":x.mean() - y_.mean(),
        "t":t, "p_raw":p
    })

    # print(rows)

res=pd.DataFrame(rows)

res["p_holm"]=multipletests(res["p_raw"], method="holm")[1]
res["sig_0.05_holm"]=res["p_holm"]<0.05

res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#     grp1   grp2   n1   n2    mean_1    mean_2      diff         t     p_raw  \
# 0    <25    45+  156   68  0.448718  0.602941 -0.154223 -2.145071  0.033820
# 1  35–44    <25  320  156  0.546875  0.448718  0.098157  2.015096  0.044765
# 2  35–44  25–34  320  707  0.546875  0.489392  0.057483  1.709448  0.087870
# 3  25–34    45+  707   68  0.489392  0.602941 -0.113549 -1.811954  0.073706
# 4  35–44    45+  320   68  0.546875  0.602941 -0.056066 -0.850074  0.397349
# 5  25–34    <25  707  156  0.489392  0.448718  0.040674  0.921109  0.357964
#
#      p_holm  sig_0.05_holm
# 0  0.202919          False
# 1  0.223826          False
# 2  0.294824          False
# 3  0.294824          False
# 4  0.715927          False
# 5  0.715927          False

# %% [markdown]
# ### <span style="color:orange">`leave_*`: Leave comfort vs Treatment rate</span>

# %%
df["leave_ord"] = df["leave"].astype(CategoricalDtype(categories={"Very easy":"Very easy", "Somewhat easy":"Somewhat easy", "Somewhat difficult":"Somewhat difficult", "Very difficult":"Very difficult", "Don't know":"Don't know"}))

df["leave_ord2"] = df["leave"].map({"Very easy": "Easy", "Somewhat easy": "Easy", "Somewhat difficult": "Difficult", "Very difficult": "Difficult", "Don't know": "Don't know"})

df["leave_ord2"] = df["leave_ord2"].astype(CategoricalDtype(categories={"Easy":"Easy", "Difficult":"Difficult", "Don't know":"Don't know"}))

print(df["leave_ord2"])

g = sns.histplot(data=df, x="leave_ord2", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Leave comfort") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Leave comfort vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()
# Out:
# 0             Easy
# 1       Don't know
# 2        Difficult
# 3        Difficult
# 4       Don't know
#            ...
# 1254          Easy
# 1255     Difficult
# 1256     Difficult
# 1257    Don't know
# 1258    Don't know
# Name: leave_ord2, Length: 1259, dtype: category
# Categories (3, object): ['Easy', 'Difficult', 'Don't know']

# %%
g = sns.catplot(data=df, x="leave_ord2", y="treat_bin", estimator=np.mean, errorbar=("ci", 95), kind="bar", hue="leave_ord2", palette="spring")
g.set(ylim=(0, 1)) 
g.figure.suptitle("Leave comfort → Treatment seeking rate", y=1.04)
g.set_axis_labels(x_var="Leave comfort", y_var="Treatment seeking rate")
plt.show()

# %%
#building a dictionary that holds the values of `care_options` variables as keys and corresponding `treat_bin` values as values
y = df["treat_bin"].astype(float)

groups={}
for seek in (df['leave_ord2'].dropna().to_numpy()):
    groups[seek]=y[df['leave_ord2'].eq(seek)].dropna().to_numpy()

# print(groups)
rows=[]
for g1, g2 in combinations(groups, 2):
    x,y_=groups[g1],groups[g2]
    t,p=stats.ttest_ind(x,y_,equal_var=False)
    rows.append({
        "grp1":g1, "grp2":g2,
        "n1":x.size, "n2":y_.size,
        "mean_1":x.mean(), "mean_2":y_.mean(),
        "diff":x.mean() - y_.mean(),
        "t":t, "p_raw":p
    })

    # print(rows)

res=pd.DataFrame(rows)

res["p_holm"]=multipletests(res["p_raw"], method="holm")[1]
res["sig_0.05_holm"]=res["p_holm"]<0.05

res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#          grp1        grp2   n1   n2    mean_1    mean_2      diff         t  \
# 0  Don't know   Difficult  563  224  0.451155  0.665179 -0.214024 -5.641359
# 1        Easy   Difficult  472  224  0.495763  0.665179 -0.169416 -4.331946
# 2        Easy  Don't know  472  563  0.495763  0.451155  0.044608  1.431293
#
#           p_raw        p_holm  sig_0.05_holm
# 0  3.063786e-08  9.191358e-08           True
# 1  1.814941e-05  3.629882e-05           True
# 2  1.526588e-01  1.526588e-01          False

# %% [markdown]
# ### <span style="color:orange">`work_interference_cat`: Whether mental health interferes with work vs Treatment rate</span>

# %%
df["work_interfere_cat"] = df["work_interfere"].astype(CategoricalDtype(categories=["Never", "Rarely", "Sometimes", "Often"]))

g = sns.histplot(data=df, x="work_interfere_cat", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Work interference") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Work interference vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
g = sns.barplot(data=df, x="work_interfere_cat", y="treat_bin", palette="colorblind", estimator=np.mean, errorbar=("ci", 95), dodge=False, hue="work_interfere_cat", legend=False, order=["Often", "Sometimes", "Rarely", "Never"])
g.set(ylim=(0,1))
g.figure.suptitle("Mental health interferes with work → Treatment seeking rate")
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("Mental health interferes with work")
plt.show()

# %%
#building a dictionary that holds the values of `care_options` variables as keys and corresponding `treat_bin` values as values
y = df["treat_bin"].astype(float)

groups={}
for inter in (df['work_interfere_cat'].dropna().to_numpy()):
    groups[inter]=y[df['work_interfere_cat'].eq(inter)].dropna().to_numpy()

# print(groups)
rows=[]
for g1, g2 in combinations(groups, 2):
    x,y_=groups[g1],groups[g2]
    t,p=stats.ttest_ind(x,y_,equal_var=False)
    rows.append({
        "grp1":g1, "grp2":g2,
        "n1":x.size, "n2":y_.size,
        "mean_1":x.mean(), "mean_2":y_.mean(),
        "diff":x.mean() - y_.mean(),
        "t":t, "p_raw":p
    })

    # print(rows)

res=pd.DataFrame(rows)

res["p_holm"]=multipletests(res["p_raw"], method="holm")[1]
res["sig_0.05_holm"]=res["p_holm"]<0.05

res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#      grp1       grp2   n1   n2    mean_1    mean_2      diff          t  \
# 0   Never  Sometimes  213  465  0.140845  0.769892 -0.629047 -20.381150
# 1   Often      Never  144  213  0.854167  0.140845  0.713322  18.785403
# 2  Rarely      Never  173  213  0.705202  0.140845  0.564357  13.378558
# 3   Often     Rarely  144  173  0.854167  0.705202  0.148964   3.266444
# 4   Often  Sometimes  144  465  0.854167  0.769892  0.084274   2.380877
# 5  Rarely  Sometimes  173  465  0.705202  0.769892 -0.064690  -1.622087
#
#           p_raw        p_holm  sig_0.05_holm
# 0  2.451566e-67  1.470940e-66           True
# 1  8.732626e-53  4.366313e-52           True
# 2  1.205312e-32  4.821248e-32           True
# 3  1.209748e-03  3.629243e-03           True
# 4  1.794208e-02  3.588416e-02           True
# 5  1.058820e-01  1.058820e-01          False

# %%
g = sns.histplot(data=df, x="work_interfere_cat_2", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Work interference") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Work interference vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
g = sns.barplot(data=df, x="work_interfere_cat_2", y="treat_bin", palette="colorblind", estimator=np.mean, errorbar=("ci", 95), dodge=False, hue="work_interfere_cat_2", legend=False, order=["Never/Rarely", "Sometimes/Often"])
g.set(ylim=(0,1))
g.figure.suptitle("Mental health interferes with work → Treatment seeking rate")
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("Mental health interferes with work")
plt.show()

# %%
df["work_interfere_cat_2"].value_counts()
# Out:
# work_interfere_cat_2
# Sometimes/Often    609
# Never/Rarely       386
# Name: count, dtype: int64

# %%
# two masks
wi2_mask_1 = df["work_interfere_cat_2"].eq("Never/Rarely")
wi2_mask_2 = df["work_interfere_cat_2"].eq("Sometimes/Often")

# pull the binary outcome; drop missing, make numeric arrays
g_wi2_1 = df.loc[wi2_mask_1, "treat_bin"].dropna().astype(float).to_numpy()
g_wi2_2 = df.loc[wi2_mask_2, "treat_bin"].dropna().astype(float).to_numpy()

alpha = 0.05

# Welch’s t-test (safer with unequal variances)
t_stat, p_val = stats.ttest_ind(g_wi2_1, wi2_mask_2, equal_var=False)

print(f"n_never_rarely={g_wi2_1.size}, n_sometimes_often={g_wi2_2.size}")
print(f"mean_never_rarely={g_wi2_1.mean():.3f}, mean_sometimes_often={g_wi2_2.mean():.3f}, diff={g_wi2_1.mean()-g_wi2_2.mean():.3f}")
print(f"t={t_stat:.3f}, p={p_val:.6f}")

if p_val < alpha:
    print("Reject H0: groups differ.")
else:
    print("Fail to reject H0: no evidence of a difference.")
# Out:
# n_never_rarely=386, n_sometimes_often=609
# mean_never_rarely=0.394, mean_sometimes_often=0.790, diff=-0.396
# t=-3.143, p=0.001746
# Reject H0: groups differ.

# %% [markdown]
# ### <span style="color:orange">`company_size_*`</span> <span style="color:pink"> by Leave comfort</span>

# %%
df["leave_ord"] = df["leave"].astype(CategoricalDtype(categories={"Very easy":"Very easy", "Somewhat easy":"Somewhat easy", "Somewhat difficult":"Somewhat difficult", "Very difficult":"Very difficult", "Don't know":"Don't know"}))

df["leave_ord2"] = df["leave"].map({"Very easy": "Easy", "Somewhat easy": "Easy", "Somewhat difficult": "Difficult", "Very difficult": "Difficult", "Don't know": "Don't know"})

df["leave_ord2"] = df["leave_ord2"].astype(CategoricalDtype(categories={"Easy":"Easy", "Difficult":"Difficult", "Don't know":"Don't know"}))

g = sns.catplot(data=df, x="company_size_cat2", y="treat_bin", kind="point", hue="leave_ord2", hue_order=["Easy", "Difficult", "Don't know"], palette="rocket") 
g.set(xlabel="Company size", ylabel="Treatment seeking rate", ylim=(0,1))
g.legend.set_title("Leave comfort") 
g.figure.suptitle("Company size → Treatment seeking rate (by Leave comfort)", y=1.04)
plt.show()

# %% [markdown]
# ### <span style="color:orange">`comfort_coworkers_cat`: Coworker comfort vs Treatment rate</span>

# %%
g = sns.barplot(data=df, x="comfort_coworkers_cat", y="treat_bin", estimator=np.mean, errorbar=("ci", 95), dodge=False, palette="mako", hue="comfort_coworkers_cat")
g.figure.suptitle("Coworker comfort vs Treatment seeking rate")
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("Coworker comfort")
g.set(ylim=(0,1))
plt.show()

# %% [markdown]
# ### <span style="color:orange">`supervisor_coworkers_cat`: Supervisor comfort vs Treatment rate</span>

# %%
g = sns.barplot(data=df, x="comfort_supervisor_cat" , y="treat_bin", estimator=np.mean, errorbar=("ci", 95), dodge=False, hue="comfort_supervisor_cat", palette="rocket")
g.figure.suptitle("Supervisor comfort vs Treatment seeking rate")
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("Supervisor comfort")
g.set(ylim=(0,1))
plt.show()

# %% [markdown]
# ### <span style="color:orange">`mental_vs_physical`: Employers view on mental vs physical health vs Treatment rate</span>

# %%
g = sns.barplot(data=df, x="mental_vs_physical", y="treat_bin", palette="tab20", estimator=np.mean, errorbar=("ci", 95), dodge=False, hue="mental_vs_physical", order=["Yes", "No", "Don't know"])
g.set(ylim=(0,1))
g.figure.suptitle("Mental vs Physical (Employer's view) → Treatment seeking rate")
g.set_ylabel("Treatment seeking rate")
g.set_xlabel("Employer's view")
plt.show()

# %% [markdown]
# ### <span style="color:orange">`family_history`: Family history of mental illness vs Treatment rate</span>

# %%
g = sns.histplot(data=df, x="family_history", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix")
g.set_xlabel("Family history") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Family history vs Treatment seeking")

g.legend_.set_title("Sought treatment")

plt.show()

# %%
g = sns.barplot(data=df, x="family_history", y="treat_bin", palette="gnuplot", estimator=np.mean, errorbar=("ci", 95), dodge=False, hue="family_history", order=["Yes","No"])
g.set(ylim=(0,1))
g.figure.suptitle("Family history vs Treatment seeking rate")
g.set_xlabel("Family history")
g.set_ylabel("Treatment seeking rate")
plt.show()

# %%
# two masks
fml_hist_mask = df["family_history"].eq("Yes")
no_fml_hist_mask = df["family_history"].eq("No")

# pull the binary outcome; drop missing, make numeric arrays
g_fml_hist = df.loc[fml_hist_mask, "treat_bin"].dropna().astype(float).to_numpy()
g_no_fml_hist = df.loc[no_fml_hist_mask, "treat_bin"].dropna().astype(float).to_numpy()

alpha = 0.05

# Welch’s t-test (safer with unequal variances)
t_stat, p_val = stats.ttest_ind(g_fml_hist, g_no_fml_hist, equal_var=False)

print(f"n_us={g_fml_hist.size}, n_non_us={g_no_fml_hist.size}")
print(f"mean_us={g_fml_hist.mean():.3f}, mean_non_us={g_no_fml_hist.mean():.3f}, diff={g_fml_hist.mean()-g_no_fml_hist.mean():.3f}")
print(f"t={t_stat:.3f}, p={p_val:.6f}")

if p_val < alpha:
    print("Reject H0: groups differ.")
else:
    print("Fail to reject H0: no evidence of a difference.")
# Out:
# n_us=492, n_non_us=767
# mean_us=0.742, mean_non_us=0.355, diff=0.387
# t=14.755, p=0.000000
# Reject H0: groups differ.

# %%
policies = ["benefits", "care_options", "seek_help", "anonymity", "wellness_program"]
# Policies/visibility (supportive = 1)
support_map = {"Yes": 1, "No": 0, "Don't know":0, "Not sure": 0}

def binner(s: pd.Series) -> pd.Series:
    """Map Yes/No/Don't know/Not Sure to 1/0."""
    return (s.map(support_map).fillna(0).astype(int))

# Build 0/1 columns for each policy and the full score (0–5)
P = {p: binner(df[p]) for p in policies}

df_policy = pd.DataFrame(P, index=df.index)

df_policy.head()

# score_check=df_policy.sum(axis=1)
# mismatch=(df["support_score"].astype(int) != score_check).sum()
# print(f"Support_score mismatches: {mismatch}")

y = df["treat_bin"].astype(int)
score_full=df["support_score"].astype(int)

mask = y.notna() & score_full.notna()

y = y[mask]
X_full = score_full[mask].to_frame(name="score").values #scikit-learn needs 2D X, even if there is only one feature

# %% [markdown]
# ### <span style="color:orange">`consequence_4cat`: Consequence concordance vs Treatment rate</span>

# %%
g = sns.catplot(data=df, x="consequence_4cat", kind="count", hue="consequence_4cat", palette="cubehelix")
g.figure.suptitle("Consequence concordance", y=1.05)
g.set_xlabels("")
g.set_ylabels("Count")
g.set_xticklabels(rotation=45, ha="right")
plt.show()

# %%
g = sns.histplot(data=df, x="consequence_4cat", hue="treatment",
             multiple="stack", stat="count", shrink=0.8,
             discrete=True, hue_order=["No","Yes"], palette="cubehelix", legend=True)
g.set_xlabel("Consequence concordance") 
g.set_ylabel("Number of employees")
g.figure.suptitle("Consequence concordance vs Treatment seeking")
g.legend_.set_title("Sought treatment")
plt.setp(g.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')

plt.show()

# %%
g = sns.catplot(data=df, x="consequence_4cat", y="treat_bin", palette="gnuplot", kind= "bar", estimator=np.mean, errorbar=("ci", 95), dodge=False, hue="consequence_4cat")
g.set(ylim=(0,1))
g.figure.suptitle("Consequence concordance vs Treatment seeking rate", y=1.05)
g.set_xlabels("Consequence concordance")
g.set_ylabels("Treatment seeking rate")
g.set_xticklabels(rotation=45, ha="right")
plt.show()

# %%
#building a dictionary that holds the values of `care_options` variables as keys and corresponding `treat_bin` values as values
y = df["treat_bin"].astype(float)

groups={}
for conc in (df['consequence_4cat'].dropna().to_numpy()):
    groups[conc]=y[df['consequence_4cat'].eq(conc)].dropna().to_numpy()

# print(groups). 
rows=[]
for g1, g2 in combinations(groups, 2): 
    x,y_=groups[g1],groups[g2]
    t,p=stats.ttest_ind(x,y_,equal_var=False)
    rows.append({
        "grp1":g1, "grp2":g2,
        "n1":x.size, "n2":y_.size,
        "mean_1":x.mean(), "mean_2":y_.mean(),
        "diff":x.mean() - y_.mean(),
        "t":t, "p_raw":p
    })

    # print(rows)

res=pd.DataFrame(rows)

res["p_holm"]=multipletests(res["p_raw"], method="holm")[1]
res["sig_0.05_holm"]=res["p_holm"]<0.05

res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#                               grp1                          grp2   n1   n2  \
# 0  Neither mental nor physical bad       Mental bad physical not  482  443
# 1  Neither mental nor physical bad  Both mental and physical bad  482  326
# 2  Neither mental nor physical bad       Pyhsical bad mental not  482    8
# 3          Mental bad physical not  Both mental and physical bad  443  326
# 4          Mental bad physical not       Pyhsical bad mental not  443    8
# 5     Both mental and physical bad       Pyhsical bad mental not  326    8
#
#      mean_1    mean_2      diff         t     p_raw    p_holm  sig_0.05_holm
# 0  0.425311  0.564334 -0.139023 -4.261219  0.000022  0.000135           True
# 1  0.425311  0.542945 -0.117634 -3.298659  0.001021  0.005105           True
# 2  0.425311  0.625000 -0.199689 -1.083119  0.313624  1.000000          False
# 3  0.564334  0.542945  0.021389  0.588765  0.556209  1.000000          False
# ...

# %% [markdown]
# ## <span style="color:Magenta">Qestion: Do workplace policies (benefits, care options, anonymity, generous leave) correlate with lower work interference?</span>

# %% [markdown]
# ### <span style="color:orange">`family_history`: Family history of mental illness vs Work interference severity</span>

# %%
df["work_interfere_sev"].unique()
# Out:
# array([ 3.,  1.,  0.,  2., nan])

# %%
g = sns.barplot(data=df, x="family_history", y="work_interfere_sev", palette="dark", estimator=np.mean, errorbar=("ci", 95), dodge=False, hue="family_history", order=["Yes", "No"])
g.set(ylim=(0,4))
g.figure.suptitle("Family history vs Work interference")
g.set_xlabel("Family history")
g.set_ylabel("Work interference severity")
plt.show()

# %%
g = sns.pointplot(data=df, x="company_size_cat", y="work_interfere_sev")
g.set(ylim=(0,3))
plt.show()

# %%
g= sns.pointplot(data=df, x="company_size_cat2", y="work_interfere_sev", estimator=np.mean, errorbar=("ci", 95), dodge=False)
g.set(xlabel="Company size", ylabel="Work interference score", ylim=(0,3))
plt.show()

# %%
g = sns.pointplot(data=df, x="company_size_cat2", y="treat_bin")
g.set(xlabel="Company size", ylabel="Treatment rate", ylim=(0,1))
plt.show()

# %%
df["gender_3"].unique()
# Out:
# array(['Woman', 'Man', 'Non-binary_GNC', 'Unknown/Other'], dtype=object)

# %%
df["gender_2"] = df["gender_3"].where(df["gender_3"].isin(["Woman", "Man"]), pd.NA)

df["gender_2"] = df["gender_2"].astype(CategoricalDtype(categories=["Woman", "Man"], ordered=False))

#Sanity check
print(df["gender_2"].value_counts(dropna=False))

g= sns.barplot(data=df, x="gender_2", y="work_interfere_sev", estimator=np.mean, errorbar=("ci", 95), dodge=False, palette="pastel", hue="gender_2", legend=False)
g.set(ylim=(0, 3)) 
g.set_xlabel("Gender")
g.set_ylabel("Work interference severity")
g.figure.suptitle("Work interference severity vs Gender")
plt.show()
# Out:
# gender_2
# Man      993
# Woman    251
# NaN       15
# Name: count, dtype: int64

# %%
# g = sns.barplot(data=df, y="treat_bin", x = "support_score", estimator=np.mean, errorbar=("ci", 95), dodge=False, palette="viridis")
# g.figure.suptitle("Support → Treatment rate")
# g.set_xlabel("Support score")
# g.set_ylabel("Treatment rate")

# %%
import numpy as np
import pandas as pd
from itertools import combinations
from scipy import stats
from statsmodels.stats.multitest import multipletests

# 0) Ensure the outcome is numeric 0/1 and drop NAs
y = df["treat_bin"].astype(float)

# 1) Build arrays per support group
groups = {}
for s in sorted(df["support_score"].dropna().unique()):
    groups[s] = y[df["support_score"].eq(s)].dropna().to_numpy()

# Optional: skip tiny groups
# groups = {k:v for k,v in groups.items() if v.size >= 10}

# 2) Pairwise Welch t-tests (safer than equal_var=True)
rows = []
for g1, g2 in combinations(sorted(groups), 2):
    x, y_ = groups[g1], groups[g2]
    t, p = stats.ttest_ind(x, y_, equal_var=False)
    rows.append({
        "grp1": g1, "grp2": g2,
        "n1": x.size, "n2": y_.size,
        "mean1": x.mean(), "mean2": y_.mean(),
        "diff": x.mean() - y_.mean(),
        "t": t, "p_raw": p
    })

res = pd.DataFrame(rows)

# 3) Multiple-comparison correction (Holm and Bonferroni)
# res["p_bonf"] = multipletests(res["p_raw"], method="bonferroni")[1]
res["p_holm"] = multipletests(res["p_raw"], method="holm")[1]
res["sig_0.05_holm"] = res["p_holm"] < 0.05

# 4) Nicely sorted view
res = res.sort_values("p_holm").reset_index(drop=True)
res
# Out:
#     grp1  grp2   n1   n2     mean1     mean2      diff         t  \
# 0      0     3  517  115  0.367505  0.704348 -0.336843 -7.058800
# 1      0     2  517  203  0.367505  0.586207 -0.218702 -5.381939
# 2      0     4  517   92  0.367505  0.652174 -0.284669 -5.247184
# 3      0     5  517   81  0.367505  0.666667 -0.299162 -5.265292
# 4      0     1  517  251  0.367505  0.529880 -0.162376 -4.268754
# 5      1     3  251  115  0.529880  0.704348 -0.174467 -3.283599
# 6      1     5  251   81  0.529880  0.666667 -0.136786 -2.226534
# 7      2     3  203  115  0.586207  0.704348 -0.118141 -2.147124
# 8      1     4  251   92  0.529880  0.652174 -0.122293 -2.070330
# 9      1     2  251  203  0.529880  0.586207 -0.056326 -1.201631
# 10     2     4  203   92  0.586207  0.652174 -0.065967 -1.085428
# 11     2     5  203   81  0.586207  0.666667 -0.080460 -1.275596
# 12     3     4  115   92  0.704348  0.652174  0.052174  0.793850
# ...

# %%
# 1) Overall: Support → Work interference severity (95% CI)
ax = sns.pointplot(
    data=df, x="support_score", y="work_interfere_sev",
    estimator=np.mean, errorbar=("ci", 95), dodge=False, color="darkblue"
)
ax.set(xlabel="Support score (0–5)", ylabel="Work interference rate", ylim=(0, 4),
       title="Support → Work Interference (95% CI)")
plt.show()

# %%
# 1) Overall: Support → Work interference severity (95% CI)
ax = sns.pointplot(
    data=df, x="support_score", y="work_interfere_sev_2",
    estimator=np.mean, errorbar=("ci", 95), dodge=False, color="darkblue"
)
ax.set(xlabel="Support score (0–5)", ylabel="Work interference rate", ylim=(0, 1),
       title="Support → Work Interference (95% CI)")
plt.show()

# %%
wi2_order = {"Never/Rarely": 0, "Sometimes/Often": 1} # leave missing values as a separate category 
df["work_interfere_sev_2"] = df["work_interfere_cat_2"].map(wi2_order)

# 1) Overall: Support → Work interference severity (95% CI)
ax = sns.pointplot(
    data=df, x="work_interfere_sev_2", y="support_score",
    estimator=np.mean, errorbar=("ci", 95), dodge=False, color="darkblue"
)
ax.set(xlabel="Work interference rate", ylabel="Support score (0–5)", ylim=(0, 5),
       title="Support → Work Interference (95% CI)")
plt.show()

# %%
# 1) Overall: Support → Work interference severity (95% CI)
ax = sns.pointplot(
    data=df, x="support_score", y="work_interfere_sev",
    estimator=np.mean, errorbar=("ci", 95), dodge=False, color="darkblue"
)
ax.set(xlabel="Support score (0–5)", ylabel="Work interference rate", ylim=(0, 4),
       title="Support → Work Interference (95% CI)")
plt.show()

# %%
# 2) Small multiples by company size
g = sns.catplot(
    data=df, x="support_score", y="work_interfere_sev",
    col="company_size_cat2", col_wrap=3, kind="point",
    estimator=np.mean, errorbar=("ci", 95), dodge=False,
    height=3.5, aspect=1.5, color="red"
)

g.set_axis_labels("Support score (0–5)", "Work interference rate")
g.set(ylim=(0, 4))
g.set_titles(col_template="{col_name}")

fig = g.figure

fig.suptitle("Support → Work Interference (95% CI) by Company Size", fontsize=14)

fig.tight_layout()
fig.subplots_adjust(bottom=0, top=.75, left=0.08, right=0.98)  # margins
fig.subplots_adjust(wspace=0.25, hspace=0.35) # spacing between facets
plt.show()

# %%
# 3) Small multiples by company size
g = sns.catplot(
    data=df, x="support_score", y="work_interfere_sev",
    col="gender_2", col_wrap=3, kind="point",
    estimator=np.mean, errorbar=("ci", 95), dodge=False,
    height=3.5, aspect=1.5, color="red"
)

g.set_axis_labels("Support score (0–5)", "Work interference rate")
g.set(ylim=(0, 4))
g.set_titles(col_template="{col_name}")
plt.show()

# %%
# 2) Small multiples by company size
g = sns.catplot(
    data=df, x="support_score", y="work_interfere_sev",
    col="us_category", col_wrap=3, kind="point",
    estimator=np.mean, errorbar=("ci", 95), dodge=False,
    height=3.5, aspect=1.5, color="red"
)

g.set_axis_labels("Support score (0–5)", "Work interference rate")
g.set(ylim=(0, 4))
g.set_titles(col_template="{col_name}")

plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <b>Insight:</b>
#
# * Work interference (0–3 scale) hovers around 1.4–1.8 across support levels
#
# * Error bars (95% CIs) overlap a lot, so differences between support scores are small/uncertain
#
# * No clear “more support → less interference” pattern in the aggregate
#
# * Confounding / reverse causality: orgs with more visible support may also be places with heavier workloads or higher need, so interference stays similar
# </div>

# %% [markdown]
# ## <span style="color:orange">Question: Is there a mismatch between willingness to discuss mental vs physical health (interview/leave consequences questions), and does that gap predict treatment or interference?</span>

# %% [markdown]
# <span style="color:orange"> Quick reminder</span>
# * `mental_health_consequence`: Do you think that discussing a mental health issue with your employer would have negative consequences? <span style="color:pink">(Yes/Maybe->negative, No->Positive)</span>
# * `phys_health_consequence`: Do you think that discussing a physical health issue with your employer would have negative consequences? <span style="color:pink">(Yes/Maybe->negative, No->Positive)</span>
# * `mental_health_interview`: Would you bring up a mental health issue with a potential employer in an interview? <span style="color:pink">(Yes/Maybe->negative, No->Positive)</span>
# * `phys_health_interview`: Would you bring up a physical health issue with a potential employer in an interview? <span style="color:pink">(Maybe/No->Negative, Yes->Positive)</span>

# %%
sns.set_theme()

# Crosstabs (keep order; fill missing combos with 0)
ct = pd.crosstab(df["parity_gap_interview_cat"], df["parity_gap_consequence_cat"])
print(ct)

# Row percentages (avoid divide-by-zero if a row is entirely 0)
ct_pct = ct.div(ct.sum(axis=1).replace(0, np.nan), axis=0) * 100
print(ct_pct)

# Plot
fig, ax = plt.subplots(1, 2, figsize=(10, 4), sharey=True)

sns.heatmap(ct, annot=True, fmt="d", cmap="Blues", cbar=False, ax=ax[0])
ax[0].set_title("Mismatch (counts)") 
ax[0].set_xlabel("Consequence gap")
ax[0].set_ylabel("Interview gap")

sns.heatmap(ct_pct.round(1), annot=True, fmt=".1f", cmap="Blues", cbar=True, ax=ax[1])
ax[1].set_title("Mismatch (row %)")
ax[1].set_xlabel("Consequence gap")
ax[1].set_ylabel("")

fig.suptitle("Parity gap mismatch: Interview vs Consequence", y=1.04)
fig.tight_layout()
plt.show()
# Out:
# parity_gap_consequence_cat  Physical worse  No gap  Mental worse
# parity_gap_interview_cat
# Physical worse                           0       3             0
# No gap                                   5     725           365
# Mental worse                             3      80            78
# parity_gap_consequence_cat  Physical worse      No gap  Mental worse
# parity_gap_interview_cat
# Physical worse                    0.000000  100.000000      0.000000
# No gap                            0.456621   66.210046     33.333333
# Mental worse                      1.863354   49.689441     48.447205

# %% [markdown]
# <div class="alert alert-info">
# <b>Insight:</b>
#
# * “No gap” = the two coded values are the same, so the difference is 0. It does not mean “good” or “no problem”; it only means mental and physical are judged equally on that question. So “No gap” can be equally positive (both safe/comfortable) or equally negative (both risky/reluctant).
#
# * Overall agreement (~64%)
#     * Diagonal cells = agreement between the two framings. You have 725 (“No gap/No gap”) + 78 (“Mental worse/Mental worse”) = 803 of 1,259 → 63.8% agreement. Almost no one says “Physical worse” in either item (n≈3–8).
#
# * Biggest mismatch: “No gap” (interview) → “Mental worse” (consequence)
#
#     * The cell No gap (interview) × Mental worse (consequence) has 365 respondents—33.3% of that row and ~29% of the whole sample.
#
#         * Interpretation: many people say they’d be equally willing to discuss mental vs physical in an interview, yet they still believe discussing mental health carries worse consequences.
#
# * When interview says “Mental worse,” consequence is split
#
#     * For the “Mental worse” interview row, the consequence column splits about 50/50 between No gap (80, 49.7%) and Mental worse (78, 48.4%).
#
#         * Interpretation: reluctance to talk about mental health doesn’t always come with a belief that consequences are worse—it’s related, but not the same construct.
#
# * “Physical worse” is negligible
#     * Counts are tiny (row totals 3–8). It’s safe to treat “Physical worse” as a very rare view; cluster it with “No gap” or flag as sparse when modeling.
#
# **Perceived consequence risks are not the same as interview comfort: ~1 in 3 respondents who feel no interview gap still think consequences are worse for mental health. Agreement across the two framings is only ~64%.**
#
# </div>

# %% [markdown]
# ## <span style="color:orange">Question: Does the level of perceived stigma about mental healt alter treatment seeking behavior or affect how enployees feel about asking for a mental health related leave? </span>

# %%
# Add 0/1 for treatment: `treat_bin` to `df`
df["treat_bin"] = df["treatment"].str.strip().str.casefold().map({"yes":1,"no":0}).astype("Int64")

# 1) Overall: Support → Treatment (95% CI)
ax = sns.pointplot(
    data=df, x="stigma_index", y="treat_bin",
    estimator=np.mean, errorbar=("ci", 95), dodge=False, color="darkblue"
)
ax.set(xlabel="Stigma Index (0–4)", ylabel="Treatment rate", ylim=(0, 1),
       title="Stigma → Treatment (95% CI)")
plt.show()

# %%
# 2) Small multiples by company size
g = sns.catplot(
    data=df, x="stigma_index", y="treat_bin",
    col="company_size_cat2", col_wrap=3, kind="point",
    estimator=np.mean, errorbar=("ci", 95), dodge=False,
    height=3.5, aspect=1.5, color="red"
)

g.set_axis_labels("Stigma Index (0–4)", "Treatment rate")
g.set(ylim=(0, 1))
g.set_titles(col_template="{col_name}")

fig = g.figure

fig.suptitle("Stigma → Treatment (95% CI) by Company Size", fontsize=14)

fig.tight_layout()
fig.subplots_adjust(bottom=0, top=.75, left=0.08, right=0.98)  # margins
fig.subplots_adjust(wspace=0.25, hspace=0.35) # spacing between facets

plt.show()

# %%
df["leave"].unique() # How easy is it for you to take medical leave for a mental health condition?
# Out:
# array(['Somewhat easy', "Don't know", 'Somewhat difficult',
#        'Very difficult', 'Very easy'], dtype=object)

# %%
df["stigma_index"].unique()

df["leave_ord"] = df["leave"].astype(CategoricalDtype(categories={"Very easy":"Very easy", "Somewhat easy":"Somewhat easy", "Somewhat difficult":"Somewhat difficult", "Very difficult":"Very difficult", "Don't know":"Don't know"}))

df["stigma_index_cat"] = df["stigma_index"].astype(CategoricalDtype(categories=[4,3,2,1,0], ordered=True))

crt = pd.crosstab(df["stigma_index_cat"], df["leave_ord"])

crt_pct = crt.div(crt.sum(axis=1).replace(0, np.nan), axis=0) * 100

fig, ax = plt.subplots(1, 2, figsize = (10, 4), sharey=True)

sns.heatmap(crt, annot=True, fmt="d", cmap="Blues", cbar=False, ax=ax[0])
ax[0].set_title("Match (counts)")
ax[0].set_xlabel("Leave comfort")
ax[0].set_ylabel("Stigma index")

sns.heatmap(crt_pct.round(1), annot=True, fmt=".1f", cmap="Blues", cbar=True, ax=ax[1])
ax[1].set_title("Match (row %)")
ax[1].set_xlabel("Leave comfort")
ax[1].set_ylabel("")

fig.suptitle("Matches: Leave vs Stigma Index", y=1.04)
fig.tight_layout()
plt.show()

# %%
df["leave_ord"] = df["leave"].astype(CategoricalDtype(categories={"Very easy":"Very easy", "Somewhat easy":"Somewhat easy", "Somewhat difficult":"Somewhat difficult", "Very difficult":"Very difficult", "Don't know":"Don't know"}))

df["leave_ord2"] = df["leave"].map({"Very easy": "Easy", "Somewhat easy": "Easy", "Somewhat difficult": "Difficult", "Very difficult": "Difficult", "Don't know": "Don't know"})

df["leave_ord2"] = df["leave_ord2"].astype(CategoricalDtype(categories={"Easy":"Easy", "Difficult":"Difficult", "Don't know":"Don't know"}))

df["stigma_index_cat2"] = df["stigma_index"].astype(CategoricalDtype(categories=[4,3,2,1,0], ordered=True))

crt2 = pd.crosstab(df["stigma_index_cat2"], df["leave_ord2"])

crt_pct2 = crt2.div(crt2.sum(axis=1).replace(0, np.nan), axis=0) * 100

fig, ax = plt.subplots(1, 2, figsize = (10, 4), sharey=True)

sns.heatmap(crt2, annot=True, fmt="d", cmap="rocket_r", cbar=False, ax=ax[0])
ax[0].set_title("Match (counts)")
ax[0].set_xlabel("Leave comfort")
ax[0].set_ylabel("Stigma index (higher = worse)")

sns.heatmap(crt_pct2.round(1), annot=True, fmt=".1f", cmap="rocket_r", cbar=True, ax=ax[1])
ax[1].set_title("Match (row %)")
ax[1].set_xlabel("Leave comfort")
ax[1].set_ylabel("")

fig.suptitle("Matches: Leave vs Stigma Index", y=1.04)
fig.tight_layout()
plt.show()

# %%
g = sns.catplot(data=df, x="leave_ord2", y="stigma_index", 
                kind="bar", estimator=np.mean, errorbar=("ci", 95), 
                col= "gender_2", col_order=["Woman", "Man"], palette="pastel", sharey=True, hue="leave_ord2")
g.set(ylim=(0, 5)) 
g.figure.suptitle("Comfort with coworkers and supervisor vs Gender", y=1.04)
g.set_axis_labels("Leave comfort", "Stigma index")
g.set_titles("{col_name}")
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <b>Insight:</b>
#
# * As stigma rises, “Easy” drops.
#
# 	* Row % for "Easy" goes from ~56–59% (stigma 0–1) → 50.7% (2) → 25.1% (3) → 25.6% (4).
#
# * “Don’t know” climbs sharply with stigma.
#
# 	* 28–31% (0–1) → 38.6% (2) → 55.0% (3) → 46.2% (4).
#
# * High-stigma environments are marked by uncertainty about leave.
#
# * “Difficult” increases at the top end.
#
# 	* ~10–16% (0–2) → ~20% (3) → ~28% (4).
#
# Counts (left panel) show most respondents sit at stigma 2–4, while stigma 0–1 are small (so treat those with caution).
#
# </div>

# %% [markdown]
# ## <span style="color:orange">Question-4: Does treatment seeking behavior differ by age or gender? </span>

# %% [markdown]
# <div class="alert alert-info">
# <b>Insight:</b>
#
# * Women ≈ 0.69 vs Men ≈ 0.46 → Women report treatment at ~20–25 percentage points higher than men.
#
# * Error bars are 95% CIs of the mean. With your large sample (Men n≈993, Women n≈251), that gap is likely statistically meaningful.
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Insight:</b>
#
# * monotonic increase: (roughly) <25 ≈ 0.45 → 25–34 ≈ 0.49 → 35–44 ≈ 0.55 → 45+ ≈ 0.60.
#
# * The 45+ CI is wide (n=68), so that estimate is less precise. The middle two groups have overlapping CIs, so their difference may be modest.
#
# * Older employees are more likely to report having received treatment, with a clear step up from <25 to mid-career, and the highest rate in 45+ (though estimated less precisely).
#
# </div>

# %%
g = sns.barplot(data=df, x="gender_2", y="comfort_any_bin", estimator=np.mean, errorbar=("ci", 95), dodge=False, palette="pastel", hue="gender_2", legend=False)
g.set(ylim=(0, 1)) 
g.set_xlabel("Gender")
g.set_ylabel("Comfort level (0-1)")
g.figure.suptitle("Comfort with coworkers and supervisor vs Gender")
plt.show()

# %%
g = sns.barplot(data=df, x="family_history", y="work_interfere_sev", palette="colorblind", estimator=np.mean, errorbar=("ci", 95), dodge=False, hue="family_history", order=["Yes","No"])
g.set(ylim=(0,4))
g.figure.suptitle("Work interference severity vs Family history")
g.set_xlabel("Family history")
g.set_ylabel("Work interference severity")
plt.show()

# %% [markdown]
# ## <span style="color:Magenta">EXTRAS</span>

# %%
# df["Timestamp"]
# df["Timestamp"].dt.month
# df["Timestamp"].dt.month_name()

month_order = ["Januay", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
g = sns.catplot(data=df, x=df["timestamp"].dt.month_name(), y="treat_bin", kind="point", order=month_order)
g.set_xticklabels(rotation=90)
plt.show()

# %% [markdown]
# <h1 style="text-align:center; color:red"> Adding year column to `df` </h1>

# %%
df["year"] = np.int64(2014)

df.head()
# Out:
#             timestamp  age  gender         country state self_employed  \
# 0 2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1 2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2 2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3 2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4 2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#   work_interfere_cat_2 treat_bin care_options_plt gender_2  \
# 0      Sometimes/Often         1       Don't know    Woman
# ...

# %% [markdown]
# <h1 style="text-align:center; color:red"> Adding 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023 survey results </h1>

# %%
df_2016 = pd.read_csv("survey_2016.csv")
df_2017 = pd.read_csv("survey_2017.csv")
df_2018 = pd.read_csv("survey_2018.csv")
df_2019 = pd.read_csv("survey_2019.csv")
df_2020 = pd.read_csv("survey_2020.csv")
df_2021 = pd.read_csv("survey_2021.csv")
df_2022 = pd.read_csv("survey_2022.csv")
df_2023 = pd.read_csv("survey_2023.csv")

# %%
df_2016.head(3)
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#   Does your employer provide mental health benefits as part of healthcare coverage?  \
# 0                    Not eligible for coverage / N/A
# ...

# %%
df_2017.head(3)
# Out:
#                                   #  <strong>Are you self-employed?</strong>  \
# 0  e49fe87572831232dcfa51b376b22039                                        0
# 1  a1eede444ac024928d247a8372d54931                                        0
# 2  37d3fd67f62bd1e0a2dea4f9cd440d98                                        0
#
#   How many employees does your company or organization have?  \
# 0                                            100-500
# 1                                            100-500
# 2                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                1.0
# 1                                                1.0
# ...

# %%
import re
import pandas as pd

CANON = ["age","gender","family_history","treatment","work_interfere",
         "benefits","care_options","seek_help","anonymity"]

# OPTIONAL: exact header mapping for specific years you’ve checked already
rename_map = {
    2016: {
        "What is your age?": "age",
        "What is your gender?": "gender",
        "Do you have a family history of mental illness?": "family_history",
        "Have you ever sought treatment for a mental health issue from a mental health professional?": "treatment",
        "If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?": "work_interfere",
        "Does your employer provide mental health benefits as part of healthcare coverage?": "benefits",
        "Do you know the options for mental health care available under your employer-provided coverage?": "care_options",
        "Did your previous employers provide resources to learn more about mental health issues and how to seek help?": "seek_help",  # canonical name
        "Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?": "anonymity",
    },
    # add more years if you want exact header matches;
    # otherwise the regex below will try to auto-map.
}

patterns = {
    "age": [r"\bage\b"],
    "gender": [r"\bgender\b"],
    "family_history": [r"family\s+history"],
    "treatment": [r"\b(sought|seek).*treat", r"ever.*treat"],
    "work_interfere": [r"interfer", r"affect.*work"],
    "benefits": [r"provide.*mental\s*health.*benefit|benefits.*mental\s*health"],
    "care_options": [r"know.*option.*(care|coverage)"],
    "seek_help": [r"(provide|previous).*resources.*(learn|mental).*seek\s*help"],
    "anonymity": [r"(anonym|privacy).*(protected|protect)"],
}

def auto_map_columns(df, year):
    out = df.copy()
    if year in rename_map:
        out = out.rename(columns=rename_map[year])
    missing = [c for c in CANON if c not in out.columns]
    if missing:
        cols = list(out.columns)
        for canon in missing:
            pats = patterns.get(canon, [])
            hit = None
            for p in pats:
                hits = [c for c in cols if re.search(p, str(c), flags=re.I)]
                if hits:
                    hit = sorted(hits, key=len, reverse=True)[0]
                    break
            if hit is not None:
                out = out.rename(columns={hit: canon})
    return out

def load_year(path, year, encoding="utf-8"):
    df = pd.read_csv(path, encoding=encoding)
    df = auto_map_columns(df, year)
    df["year"] = int(year)
    keep = ["year"] + [c for c in CANON if c in df.columns]
    return df[keep]

yes_map = {"yes":1, "no":0, "don't know":0, "not sure":0}
def bin01(s: pd.Series) -> pd.Series:
    return (s.astype("string").str.strip().str.casefold()
              .map(yes_map).fillna(0).astype(int))

# %%
import os, re, glob, pandas as pd

# 1) Search recursively for any CSVs under this folder (change '.' if needed)
ROOT = "."            # try "." (current notebook folder) OR an absolute folder path
candidates = sorted(glob.glob(os.path.join(ROOT, "**", "*.csv"), recursive=True))
print(f"Found {len(candidates)} CSVs")
for p in candidates[:12]:
    print(" •", p)

# 2) Pull a plausible year out of each filename (2014–2025)
def detect_year(path):
    m = re.search(r"(20(1[4-9]|2[0-5]))", os.path.basename(path))
    return int(m.group(1)) if m else None

by_year = {}
for p in candidates:
    yr = detect_year(p)
    if yr is None:
        continue
    # keep the *largest* file per year if multiple are found
    size = os.path.getsize(p)
    if yr not in by_year or size > os.path.getsize(by_year[yr]):
        by_year[yr] = p

print("\nMapped files by year:")
for yr in sorted(by_year):
    print(yr, "→", by_year[yr])

# If nothing printed above, set ROOT to the actual directory containing your files and re-run.
# Out:
# Found 10 CSVs
#  • ./osmi_wide_2016_2023.csv
#  • ./survey.csv
#  • ./survey_2016.csv
#  • ./survey_2017.csv
#  • ./survey_2018.csv
#  • ./survey_2019.csv
#  • ./survey_2020.csv
#  • ./survey_2021.csv
#  • ./survey_2022.csv
#  • ./survey_2023.csv
#
# Mapped files by year:
# 2016 → ./survey_2016.csv
# 2017 → ./survey_2017.csv
# 2018 → ./survey_2018.csv
# 2019 → ./survey_2019.csv
# 2020 → ./survey_2020.csv
# 2021 → ./survey_2021.csv
# 2022 → ./survey_2022.csv
# 2023 → ./survey_2023.csv

# %%
import re, pandas as pd

# Canonical targets (same as 2014 naming)
CANON = ["age","gender","family_history","treatment","work_interfere",
         "benefits","care_options","seek_help","anonymity"]

# Regex fallbacks so slight header wording changes still map
patterns = {
    "age": [r"\bage\b"],
    "gender": [r"\bgender\b"],
    "family_history": [r"family\s+history"],
    "treatment": [r"\b(sought|seek).*treat", r"ever.*treat"],
    "work_interfere": [r"interfer|affect.*work"],
    "benefits": [r"provide.*mental\s*health.*benefit|benefits.*mental\s*health"],
    "care_options": [r"know.*option.*(care|coverage)"],
    # canonical name you want:
    "seek_help": [r"(provide|previous).*resources.*(learn|mental).*seek\s*help"],
    "anonymity": [r"(anonym|privacy).*(protected|protect)"],
}

def auto_map_columns(df, year):
    out = df.copy()
    # Fill anything missing via regex
    missing = [c for c in CANON if c not in out.columns]
    if missing:
        cols = list(out.columns)
        for canon in missing:
            for p in patterns.get(canon, []):
                hits = [c for c in cols if re.search(p, str(c), flags=re.I)]
                if hits:
                    out = out.rename(columns={sorted(hits, key=len, reverse=True)[0]: canon})
                    break
    return out

def load_year_any_encoding(path, year):
    # Try utf-8 then latin-1
    for enc in ("utf-8", "latin-1"):
        try:
            df = pd.read_csv(path, encoding=enc)
            df = auto_map_columns(df, year)
            df["year"] = int(year)
            keep = ["year"] + [c for c in CANON if c in df.columns]
            return df[keep]
        except Exception as e:
            last_err = f"{type(e).__name__}: {e}"
    raise RuntimeError(f"Failed to read {path}: {last_err}")

yes_map = {"yes":1, "no":0, "don't know":0, "not sure":0}
def bin01(s: pd.Series) -> pd.Series:
    return (s.astype("string").str.strip().str.casefold()
              .map(yes_map).fillna(0).astype(int))

# ---- build wide from the discovered files in Cell A (by_year dict) ----
assert 'by_year' in globals() and isinstance(by_year, dict) and by_year, \
    "No files found in Cell A. Set ROOT to your folder and re-run Cell A."

frames, failures = [], []
for yr, path in sorted(by_year.items()):
    try:
        d = load_year_any_encoding(path, yr)
    except Exception as e:
        failures.append((yr, str(e)))
        continue

    # Ensure pillars exist so the score computes
    for col in ["benefits","care_options","seek_help","anonymity"]:
        if col not in d.columns:
            d[col] = pd.NA

    d["support_score"] = (
        bin01(d["benefits"]) +
        bin01(d["care_options"]) +
        bin01(d["seek_help"]) +
        bin01(d["anonymity"])
    ).astype("Int64")

    # treatment binary
    if "treatment" in d.columns:
        d["treat_bin"] = (d["treatment"].astype("string").str.strip().str.casefold()
                          .map({"yes":1,"no":0}).astype("Int64"))
    else:
        d["treat_bin"] = pd.NA

    frames.append(d)

print("Loaded years:", [int(x["year"].iloc[0]) for x in frames])
if failures:
    print("Failures:", failures)

if not frames:
    raise RuntimeError("No survey files loaded. Re-run Cell A and check ROOT/path mapping.")

wide = pd.concat(frames, ignore_index=True)
print("wide shape:", wide.shape)
print("wide columns:", list(wide.columns))

# Optional: save combined dataset
wide.to_csv("osmi_wide_2016_2023.csv", index=False)
print("Saved osmi_wide_2016_2023.csv in current folder.")
# Out:
# Loaded years: [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# wide shape: (3439, 12)
# wide columns: ['year', 'age', 'gender', 'family_history', 'treatment', 'work_interfere', 'benefits', 'care_options', 'seek_help', 'anonymity', 'support_score', 'treat_bin']
# Saved osmi_wide_2016_2023.csv in current folder.

# %%
df_2016_2023 = pd.read_csv("osmi_wide_2016_2023.csv")

df_2016_2023
# Out:
#       year   age  gender family_history  treatment        work_interfere  \
# 0     2016  39.0    Male             No          0  Not applicable to me
# 1     2016  29.0    male            Yes          1             Sometimes
# 2     2016  38.0   Male              No          1  Not applicable to me
# 3     2016  43.0    male             No          1             Sometimes
# 4     2016  43.0  Female            Yes          1             Sometimes
# ...    ...   ...     ...            ...        ...                   ...
# 3434  2023  36.0    Male             No          1             Sometimes
# 3435  2023  44.0    male            Yes          1                 Often
# 3436  2023  53.0  Female            Yes          1                 Often
# 3437  2023  62.0    male             No          1                 Often
# 3438  2023  39.0    Male            Yes          1                 Often
#
#                              benefits care_options seek_help     anonymity  \
# ...

# %%
df_2016_2023["benefits"].unique()
# Out:
# array(['Not eligible for coverage / N/A', 'No', nan, 'Yes',
#        "I don't know", 'Not eligible for coverage / NA'], dtype=object)

# %%
df_2016_2023["care_options"].unique()
# Out:
# array([nan, 'Yes', 'I am not sure', 'No'], dtype=object)

# %%
df_2016_2023["seek_help"].unique()
# Out:
# array(['None did', 'Some did', nan, 'Yes, they all did'], dtype=object)

# %%
df_2016_2023["anonymity"].unique()
# Out:
# array(["I don't know", 'Yes', nan, 'No'], dtype=object)

# %%
df_2016_2023["family_history"].unique()
# Out:
# array(['No', 'Yes', "I don't know"], dtype=object)

# %%
import re, pandas as pd

# Canonical targets (same as 2014 naming)
CANON = ["age","gender","family_history","treatment","work_interfere",
         "benefits","care_options","seek_help","anonymity"]

# Regex fallbacks so slight header wording changes still map
patterns = {
    "age": [r"\bage\b"],
    "gender": [r"\bgender\b"],
    "family_history": [r"family\s+history"],
    "treatment": [r"\b(sought|seek).*treat", r"ever.*treat"],
    "work_interfere": [r"interfer|affect.*work"],
    "benefits": [r"provide.*mental\s*health.*benefit|benefits.*mental\s*health"],
    "care_options": [r"know.*option.*(care|coverage)"],
    # canonical name you want:
    "seek_help": [r"(provide|previous).*resources.*(learn|mental).*seek\s*help"],
    "anonymity": [r"(anonym|privacy).*(protected|protect)"],
}

def auto_map_columns(df, year):
    out = df.copy()
    # Fill anything missing via regex
    missing = [c for c in CANON if c not in out.columns]
    if missing:
        cols = list(out.columns)
        for canon in missing:
            for p in patterns.get(canon, []):
                hits = [c for c in cols if re.search(p, str(c), flags=re.I)]
                if hits:
                    out = out.rename(columns={sorted(hits, key=len, reverse=True)[0]: canon})
                    break
    return out

def load_year_any_encoding(path, year):
    # Try utf-8 then latin-1
    for enc in ("utf-8", "latin-1"):
        try:
            df = pd.read_csv(path, encoding=enc)
            df = auto_map_columns(df, year)
            df["year"] = int(year)
            keep = ["year"] + [c for c in CANON if c in df.columns]
            return df[keep]
        except Exception as e:
            last_err = f"{type(e).__name__}: {e}"
    raise RuntimeError(f"Failed to read {path}: {last_err}")

# ---------- NEW: policy binning exactly per your rules ----------
POLICY_MAP = {
    # 1s
    "yes": 1,
    "some did": 1,
    "yes, they all did": 1,
    # 0s
    "no": 0,
    "none did": 0,
    "i don't know": 0,
    "i am not sure": 0,
    "not eligible for coverage / n/a": 0,
    "not eligible for coverage / na": 0,
}

def normalize_txt(s: pd.Series) -> pd.Series:
    # Robust normalization: strip, casefold, collapse whitespace, normalize slashes
    s = (s.astype("string")
           .str.strip()
           .str.replace("\u00A0", " ", regex=False)   # NBSP -> space
           .str.replace(r"\s*/\s*", " / ", regex=True)
           .str.replace(r"\s+", " ", regex=True)
           .str.casefold())
    return s

def policy_bin(s: pd.Series) -> pd.Series:
    # Map to {0,1} with missing kept as <NA>
    n = normalize_txt(s)
    out = n.map(POLICY_MAP)
    return out.astype("Int64")  # preserves <NA> for true missing

# Treatment: simple yes/no (keep missing as <NA>)
def treat_bin(s: pd.Series) -> pd.Series:
    n = normalize_txt(s)
    out = n.map({"yes": 1, "no": 0})
    return out.astype("Int64")

# ---- build `wide` from the discovered files in Cell A (expects `by_year`) ----
assert 'by_year' in globals() and isinstance(by_year, dict) and by_year, \
    "No files found in Cell A. Set ROOT and re-run discovery."

frames, failures = [], []
for yr, path in sorted(by_year.items()):
    try:
        d = load_year_any_encoding(path, yr)
    except Exception as e:
        failures.append((yr, str(e)))
        continue

    # Ensure pillars exist so the score computes
    for col in ["benefits","care_options","seek_help","anonymity"]:
        if col not in d.columns:
            d[col] = pd.NA

    # Encode each pillar with the new policy_bin (keeps <NA>)
    b = policy_bin(d["benefits"])
    c = policy_bin(d["care_options"])
    s = policy_bin(d["seek_help"])
    a = policy_bin(d["anonymity"])

    # Support score: sum available pillars; <NA> only if ALL four are missing
    d["support_score"] = (
        pd.concat([b, c, s, a], axis=1)
          .sum(axis=1, min_count=1)       # ignore NAs; require at least 1 non-NA
          .astype("Int64")
    )

    # Treatment binary
    if "treatment" in d.columns:
        d["treat_bin"] = treat_bin(d["treatment"])
    else:
        d["treat_bin"] = pd.NA

    frames.append(d)

print("Loaded years:", [int(x["year"].iloc[0]) for x in frames])
if failures:
    print("Failures:", failures)

if not frames:
    raise RuntimeError("No survey files loaded. Re-run discovery (Cell A) to populate by_year.")

wide = pd.concat(frames, ignore_index=True)
print("wide shape:", wide.shape)
print("wide columns:", list(wide.columns))

# Optional: quick sanity on the new coding
for col in ["benefits","care_options","seek_help","anonymity"]:
    print(f"\n{col} → coded value_counts (incl. NA):")
    print(policy_bin(wide[col]).value_counts(dropna=False))

# Optional: save
wide.to_csv("osmi_wide_2016_2023.csv", index=False)
print("Saved osmi_wide_2016_2023.csv")
# Out:
# Loaded years: [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
# wide shape: (3439, 12)
# wide columns: ['year', 'age', 'gender', 'family_history', 'treatment', 'work_interfere', 'benefits', 'care_options', 'seek_help', 'anonymity', 'support_score', 'treat_bin']
#
# benefits → coded value_counts (incl. NA):
# benefits
# 1       1453
# 0       1315
# <NA>     671
# Name: count, dtype: Int64
#
# care_options → coded value_counts (incl. NA):
# care_options
# 0       1522
# 1       1022
# <NA>     895
# Name: count, dtype: Int64
#
# seek_help → coded value_counts (incl. NA):
# seek_help
# 0       1931
# 1       1015
# <NA>     493
# Name: count, dtype: Int64
#
# anonymity → coded value_counts (incl. NA):
# anonymity
# 0       1938
# 1        913
# <NA>     588
# Name: count, dtype: Int64
# Saved osmi_wide_2016_2023.csv

# %%
df_2016_2023 = pd.read_csv("osmi_wide_2016_2023.csv")

df_2016_2023
# Out:
#       year   age  gender family_history  treatment        work_interfere  \
# 0     2016  39.0    Male             No          0  Not applicable to me
# 1     2016  29.0    male            Yes          1             Sometimes
# 2     2016  38.0   Male              No          1  Not applicable to me
# 3     2016  43.0    male             No          1             Sometimes
# 4     2016  43.0  Female            Yes          1             Sometimes
# ...    ...   ...     ...            ...        ...                   ...
# 3434  2023  36.0    Male             No          1             Sometimes
# 3435  2023  44.0    male            Yes          1                 Often
# 3436  2023  53.0  Female            Yes          1                 Often
# 3437  2023  62.0    male             No          1                 Often
# 3438  2023  39.0    Male            Yes          1                 Often
#
#                              benefits care_options seek_help     anonymity  \
# ...

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
import re

def _normalize_txt(s: pd.Series) -> pd.Series:
    return (s.astype("string")
             .str.strip()
             .str.replace("\u00A0", " ", regex=False)           # NBSP → space
             .str.replace(r"[\u2044\u2215]", "/", regex=True)   # Unicode slashes → "/"
             .str.replace(r"\s*/\s*", " / ", regex=True)        # pad slash with spaces
             .str.replace(r"\s+", " ", regex=True)              # collapse spaces
             .str.casefold())

CANON_2014 = {
    # YES bucket
    "yes": "Yes",
    "some did": "Yes",
    "yes, they all did": "Yes",

    # NO bucket
    "no": "No",
    "none did": "No",
    "not eligible for coverage / n/a": "No",
    "not eligible for coverage / na": "No",

    # DON'T KNOW bucket
    "i don't know": "Don't know",
    "i am not sure": "Don't know",
    "not sure": "Don't know",
}

def to_2014_labels(s: pd.Series) -> pd.Series:
    n = _normalize_txt(s)
    out = n.map(CANON_2014)         # returns "Yes"/"No"/"Don't know"/<NA>
    return out.astype("string")

# %%
pillars = ["benefits", "care_options", "seek_help", "anonymity"]
cat = CategoricalDtype(categories=["Yes","No","Don't know"], ordered=False)

for col in pillars:
    if col in df_2016_2023.columns:
        df_2016_2023[col] = to_2014_labels(df_2016_2023[col]).astype(cat)

# %%
df_2016_2023
# Out:
#       year   age  gender family_history  treatment        work_interfere  \
# 0     2016  39.0    Male             No          0  Not applicable to me
# 1     2016  29.0    male            Yes          1             Sometimes
# 2     2016  38.0   Male              No          1  Not applicable to me
# 3     2016  43.0    male             No          1             Sometimes
# 4     2016  43.0  Female            Yes          1             Sometimes
# ...    ...   ...     ...            ...        ...                   ...
# 3434  2023  36.0    Male             No          1             Sometimes
# 3435  2023  44.0    male            Yes          1                 Often
# 3436  2023  53.0  Female            Yes          1                 Often
# 3437  2023  62.0    male             No          1                 Often
# 3438  2023  39.0    Male            Yes          1                 Often
#
#         benefits care_options seek_help   anonymity  support_score  treat_bin
# ...

# %%
df_2016_2023["age"].unique()
# Out:
# array([ 39.,  29.,  38.,  43.,  42.,  30.,  37.,  44.,  28.,  34.,  35.,
#         52.,  32.,  25.,  31.,  26.,  33.,  27.,  36.,  40.,  46.,  41.,
#         45.,  19.,  21.,  24.,  17.,  23.,  22.,  51.,  48.,  55.,  50.,
#         49.,  20.,  54.,  47.,  56.,  57.,  63.,  99.,  61., 323.,  62.,
#         53.,  58.,   3.,  66.,  59.,  15.,  65.,  74.,  70.,  18.,  64.,
#         60.,  67.,  nan,   0.,   5.,   1.,  11., 223.,   2.,  76.])

# %%
age = pd.to_numeric(df_2016_2023["age"], errors="coerce")

# %%
outlier = age.lt(18) | age.gt(80)

df_2016_2023["age_outlier"] = outlier

# %%
bins = [0, 25, 35, 45, np.inf] 
labels = ["<25", "25-34", "35-44", "45+"]

age_cat = df_2016_2023["age_cat"] = pd.cut(
    age.where(~outlier),
    bins=bins,
    labels=labels,
    right=False,
    include_lowest=True
)

# %%
age_cat = age_cat.cat.add_categories(["Unknown", "Outlier"])
age_cat[age_cat.isna()] = "Unknown"
age_cat[outlier] = "Outlier"

df_2016_2023["age_cat"] = age_cat

df_2016_2023["age_cat"]
# Out:
# 0       35-44
# 1       25-34
# 2       35-44
# 3       35-44
# 4       35-44
#         ...
# 3434    35-44
# 3435    35-44
# 3436      45+
# 3437      45+
# 3438    35-44
# Name: age_cat, Length: 3439, dtype: category
# Categories (6, object): ['<25' < '25-34' < '35-44' < '45+' < 'Unknown' < 'Outlier']

# %%
df_2016_2023
# Out:
#       year   age  gender family_history  treatment        work_interfere  \
# 0     2016  39.0    Male             No          0  Not applicable to me
# 1     2016  29.0    male            Yes          1             Sometimes
# 2     2016  38.0   Male              No          1  Not applicable to me
# 3     2016  43.0    male             No          1             Sometimes
# 4     2016  43.0  Female            Yes          1             Sometimes
# ...    ...   ...     ...            ...        ...                   ...
# 3434  2023  36.0    Male             No          1             Sometimes
# 3435  2023  44.0    male            Yes          1                 Often
# 3436  2023  53.0  Female            Yes          1                 Often
# 3437  2023  62.0    male             No          1                 Often
# 3438  2023  39.0    Male            Yes          1                 Often
#
#         benefits care_options seek_help   anonymity  support_score  treat_bin  \
# ...

# %%
df_2016_2023["work_interfere"].unique()
# Out:
# array(['Not applicable to me', 'Sometimes', 'Often', 'Rarely', 'Never'],
#       dtype=object)

# %%
df_2016_2023["work_interfere"].value_counts()
# Out:
# work_interfere
# Often                   1364
# Not applicable to me    1136
# Sometimes                761
# Rarely                   139
# Never                     39
# Name: count, dtype: int64

# %%
df_2016_2023["gender"].unique()
# Out:
# array(['Male', 'male', 'Male ', 'Female', 'M', 'female', 'm',
#        'I identify as female.', 'female ', 'Bigender', 'non-binary',
#        'Female assigned at birth ', 'F', 'Woman', 'man', 'fm', 'f',
#        'Cis female ', 'Transitioned, M2F', 'Genderfluid (born female)',
#        'Other/Transfeminine', 'Female or Multi-Gender Femme', 'Female ',
#        'woman', 'female/woman', 'Cis male', 'Male.', 'Androgynous',
#        'male 9:1 female, roughly', nan, 'Male (cis)', 'Other',
#        'nb masculine', 'Cisgender Female', 'Man', 'Sex is male',
#        'none of your business', 'genderqueer', 'cis male', 'Human',
#        'Genderfluid', 'Enby', 'Malr', 'genderqueer woman', 'mtf', 'Queer',
#        'Agender', 'Dude', 'Fluid',
#        "I'm a man why didn't you make this a drop down question. You should of asked sex? And I would of answered yes please. Seriously how much text can this take? ",
#        'mail', 'M|', 'Male/genderqueer', 'fem', 'Nonbinary', 'male ',
# ...

# %%
df_2016_2023["gender_5"] = df_2016_2023["gender"].apply(clean_gender)

df_2016_2023["gender_3"] = df_2016_2023["gender_5"].replace({"Trans man":"Man", "Trans woman":"Woman"})

df_2016_2023["gender_3_alt"] = df_2016_2023["gender_5"].replace({"Trans woman": "Non-binary_GNC", "Trans man": "Non-binary_GNC"})

df_2016_2023["gender_3_alt"] = df_2016_2023["gender_3_alt"].replace({"Non-binary_GNC": "Trans_Non-binary_GNC", "Non-binary_GNC": "Trans_Non-binary_GNC"})

# %%
df_2016_2023["treat_bin"] = df_2016_2023["treatment"]

# %%
df_2016_2023["treatment"] = df_2016_2023["treatment"].map({1:"Yes", 0:"No"})

df_2016_2023.head()
# Out:
#    year   age  gender family_history treatment        work_interfere benefits  \
# 0  2016  39.0    Male             No        No  Not applicable to me      NaN
# 1  2016  29.0    male            Yes       Yes             Sometimes       No
# 2  2016  38.0   Male              No       Yes  Not applicable to me       No
# 3  2016  43.0    male             No       Yes             Sometimes      NaN
# 4  2016  43.0  Female            Yes       Yes             Sometimes      Yes
#
#   care_options seek_help   anonymity  support_score  treat_bin  age_outlier  \
# 0          NaN        No  Don't know            0.0          0        False
# 1          Yes       Yes         Yes            3.0          1        False
# 2          NaN       Yes  Don't know            1.0          1        False
# 3          NaN        No         NaN            0.0          1        False
# 4          Yes        No          No            2.0          1        False
#
# ...

# %%
df_2016_2023["year"].dtype
# Out:
# dtype('int64')

# %%
df_2016_2023["work_interfere"] = df_2016_2023["work_interfere"].replace({"Not applicable to me":np.nan})

df_2016_2023["work_interfere"].unique()

df_2016_2023.head()
# Out:
#    year   age  gender family_history treatment work_interfere benefits  \
# 0  2016  39.0    Male             No        No            NaN      NaN
# 1  2016  29.0    male            Yes       Yes      Sometimes       No
# 2  2016  38.0   Male              No       Yes            NaN       No
# 3  2016  43.0    male             No       Yes      Sometimes      NaN
# 4  2016  43.0  Female            Yes       Yes      Sometimes      Yes
#
#   care_options seek_help   anonymity  support_score  treat_bin  age_outlier  \
# 0          NaN        No  Don't know            0.0          0        False
# 1          Yes       Yes         Yes            3.0          1        False
# 2          NaN       Yes  Don't know            1.0          1        False
# 3          NaN        No         NaN            0.0          1        False
# 4          Yes        No          No            2.0          1        False
#
#   age_cat gender_5 gender_3 gender_3_alt
# ...

# %%
df_2016_2023["age_cat_2"] = df_2016_2023["age_cat"].where(df_2016_2023["age_cat"].isin(["<25", "25–34", "35–44", "45+"]), pd.NA)

df_2016_2023["age_cat_2"] = df_2016_2023["age_cat_2"].astype(CategoricalDtype(categories=["<25", "25–34", "35–44", "45+"], ordered=True))
